# %% [markdown]
# # Ab Initio to PySpark Code Conversion
#
# This notebook implements an Azure OpenAI service-based code conversion agent that converts Ab Initio code to PySpark. The agent will:
# 1. Read XFR files and schema layouts
# 2. Generate PySpark transformation code
# 3. Perform code review and optimization
# 4. Output production-ready PySpark code
#
# # Package Installation and Setup
# First, let's install all the required packages for our code interpreter agent. We'll use pip to install them.

# %%
# Install required packages
# !pip install openai python-dotenv pandas jupyter notebook ipykernel requests matplotlib
# %pip install --upgrade typing_extensions
# Out:
# StatementMeta(, d9203f8a-a3fe-461c-a791-1d49e6717b79, 9, Finished, Available, Finished)
# Requirement already satisfied: typing_extensions in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (4.9.0)
# Collecting typing_extensions
#   Downloading typing_extensions-4.14.0-py3-none-any.whl.metadata (3.0 kB)
# Downloading typing_extensions-4.14.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: typing_extensions
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.9.0
#     Not uninstalling typing-extensions at /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages, outside environment /nfs4/pyenv-b49682ec-eb80-4cfb-9752-ff8bedb85af6
#     Can't uninstall 'typing_extensions'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# nni 3.0 requires filelock<3.12, but you have filelock 3.13.1 which is incompatible.
# datasets 2.19.1 requires fsspec[http]<=2024.3.1,>=2023.1.0, but you have fsspec 2024.6.1 which is incompatible.
# fsspec-wrapper 0.1.15 requires PyJWT>=2.6.0, but you have pyjwt 2.4.0 which is incompatible.
# Successfully installed typing_extensions-4.14.0
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting openai
#   Downloading openai-1.84.0-py3-none-any.whl.metadata (25 kB)
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pandas in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (2.1.4)
# Collecting jupyter
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: notebook in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (7.0.8)
# Requirement already satisfied: ipykernel in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (6.28.0)
# Requirement already satisfied: requests in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (2.31.0)
# Requirement already satisfied: matplotlib in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (3.8.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from openai) (1.8.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Collecting pydantic<3,>=1.9.0 (from openai)
#   Downloading pydantic-2.11.5-py3-none-any.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from openai) (4.65.0)
# Collecting typing-extensions<5,>=4.11 (from openai)
#   Using cached typing_extensions-4.14.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy<2,>=1.23.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: jupyter-console in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jupyter) (7.10.0)
# Requirement already satisfied: ipywidgets in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jupyter) (8.1.2)
# Requirement already satisfied: jupyterlab in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jupyter) (4.0.11)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from notebook) (2.10.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from notebook) (2.25.1)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from notebook) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from notebook) (6.3.3)
# Requirement already satisfied: comm>=0.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipykernel) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipykernel) (8.20.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipykernel) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipykernel) (5.5.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: nest-asyncio in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipykernel) (23.1)
# Requirement already satisfied: psutil in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipykernel) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipykernel) (25.1.2)
# Requirement already satisfied: traitlets>=5.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipykernel) (5.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests) (2024.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: decorator in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (2.15.1)
# Requirement already satisfied: stack-data in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel) (4.8.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (3.10.0)
# Requirement already satisfied: argon2-cffi in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (21.3.0)
# Requirement already satisfied: jinja2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.3)
# Requirement already satisfied: jupyter-events>=0.6.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.4.4)
# Requirement already satisfied: nbformat>=5.3.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.9.2)
# Requirement already satisfied: overrides in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.4.0)
# Requirement already satisfied: prometheus-client in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.14.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.17.1)
# Requirement already satisfied: websocket-client in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.58.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jupyterlab->jupyter) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jupyterlab->jupyter) (2.2.0)
# Requirement already satisfied: babel>=2.10 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook) (4.19.2)
# Requirement already satisfied: beautifulsoup4 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from nbconvert->jupyter) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from nbconvert->jupyter) (4.1.0)
# Requirement already satisfied: defusedxml in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from nbconvert->jupyter) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from nbconvert->jupyter) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from nbconvert->jupyter) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from nbconvert->jupyter) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: tinycss2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from nbconvert->jupyter) (1.2.1)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->openai)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3,>=1.9.0->openai)
#   Downloading pydantic_core-2.33.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3,>=1.9.0->openai)
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets->jupyter) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets->jupyter) (3.0.10)
# Requirement already satisfied: webencodings in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook) (0.10.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: fastjsonschema in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.16.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.5)
# Requirement already satisfied: argon2-cffi-bindings in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.5)
# Requirement already satisfied: executing in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: asttokens in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.0.5)
# Requirement already satisfied: pure-eval in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.2)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=1.11 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: cffi>=1.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook) (1.16.0)
# Requirement already satisfied: pycparser in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook) (1.2.3)
# Downloading openai-1.84.0-py3-none-any.whl (725 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 725.5/725.5 kB 16.3 MB/s eta 0:00:00a 0:00:01
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 29.7 MB/s eta 0:00:00
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 32.3 MB/s eta 0:00:00
# Downloading jiter-0.10.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (352 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.2/352.2 kB 74.0 MB/s eta 0:00:00
# Downloading pydantic-2.11.5-py3-none-any.whl (444 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.2/444.2 kB 84.4 MB/s eta 0:00:00
# Downloading pydantic_core-2.33.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 73.3 MB/s eta 0:00:00
# Using cached typing_extensions-4.14.0-py3-none-any.whl (43 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: webcolors, uri-template, typing-extensions, python-dotenv, jiter, h11, fqdn, annotated-types, typing-inspection, pydantic-core, httpcore, pydantic, isoduration, httpx, openai, jupyter
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.9.0
#     Uninstalling typing_extensions-4.9.0:
#       Successfully uninstalled typing_extensions-4.9.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# nni 3.0 requires filelock<3.12, but you have filelock 3.13.1 which is incompatible.
# datasets 2.19.1 requires fsspec[http]<=2024.3.1,>=2023.1.0, but you have fsspec 2024.6.1 which is incompatible.
# fsspec-wrapper 0.1.15 requires PyJWT>=2.6.0, but you have pyjwt 2.4.0 which is incompatible.
# Successfully installed annotated-types-0.7.0 fqdn-1.5.1 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 isoduration-20.11.0 jiter-0.10.0 jupyter-1.1.1 openai-1.84.0 pydantic-2.11.5 pydantic-core-2.33.2 python-dotenv-1.1.0 typing-extensions-4.14.0 typing-inspection-0.4.1 uri-template-1.3.0 webcolors-24.11.1
# Warning: PySpark kernel has been restarted to use updated packages.

# %% [markdown]
# # Import Required Libraries
# Import necessary libraries for working with Azure OpenAI, environment variables, and data processing.

# %%
# Import necessary libraries
import openai
import pandas as pd
import requests
import matplotlib.pyplot as plt
# Out:
# StatementMeta(, d9203f8a-a3fe-461c-a791-1d49e6717b79, 11, Finished, Available, Finished)

# %%
from pydantic import BaseModel, Field
from openai import AzureOpenAI
import os
# import dependencies

import os
from openai import AzureOpenAI
from dotenv import load_dotenv
import json
import copy
import textwrap

# # Load environment variables from root directory
# from pathlib import Path
# root_env_path = Path(__file__).parent.parent / '.env'
# load_dotenv(root_env_path)

# print(f"Loading .env file from: {root_env_path}")

client = AzureOpenAI(  
    api_version="",  
    azure_endpoint="",  
    api_key="" 
)  

# class CaseStudy(BaseModel):
#     case_study_task: str = Field(..., 
#         description="You are a data engineer with expertise in Ab Initio and PySpark. You will be provided with a case study task that requires you to analyze and process data using these technologies. Your goal is to provide a solution that meets the requirements outlined in the task description.")
#     case_study_solution: str = Field(..., 
#         description="The expected solution to the case study.")


def o3minicall(prompt, reasoning_effort, response_format=None):

    system_message = """
    You are a **principal data engineer** who is fluent in both **Ab Initio XFR** and **PySpark** (Databricks).  
    Your task is to translate a given XFR file into a production-ready PySpark solution.

    ### 1. Deliverables  
    | Item | Description |
    |------|-------------|
    | **A. Modular functions** | Reusable PySpark functions that replicate every XFR rule or sub-graph.<br>• Name each function after the business rule it implements.<br>• No hard-coded paths or secrets—parameterize where appropriate. |
    | **B. Pipeline assembly** | A single `main()` (or notebook cell) that:<br>1. Reads **`input_schema`** (from the provided layout).<br>2. Sequentially applies the modular functions.<br>3. Selects / renames columns to match **`output_schema`**.<br>4. Writes the result (Parquet or table) ready for Databricks jobs. |
    | **C. Step-by-step explanation** | For every function and pipeline stage, include a concise markdown comment explaining *what* it does and *why* (1-3 sentences).<br>Focus on business logic, joins, aggregations, date maths, and default rules. |

    ### 2. Input Artifacts (available in variables)  
    * `xfr_content` - full Ab Initio logic  
    * `input_layout` - markdown layout file for the source schema  
    * `output_layout` - markdown layout file for the target schema  

    ### 3. Coding Guidelines  
    * Use **PySpark 3.x DataFrame API** only (no RDDs).  
    * Optimize for readability first; add `.cache()` only where beneficial.  
    * Follow PEP-8 naming (e.g., `add_company_number`, `calculate_policy_term`).  
    * Keep all string literals in a dedicated **`constants.py`** block (you may inline in the prompt for brevity).  
    * Validate data types explicitly; cast to `StringType` where the XFR expects `hive_string_t`.

    ### 4. Output Format  
    Provide a **single markdown code block** containing:  

    1. `import` statements and any constant dictionaries  
    2. All modular function definitions  
    3. The end-to-end pipeline assembly (`main()` or notebook cells)  
    4. Inline markdown comments for explanations  

    ---

    **Begin converting now.**


    """
    
    # Create the base parameters for the API call
    params = {
        "model": "o3",  # replace with the model deployment name
        "messages": [
            {
                "role": "user", 
                "content": system_message+" "+prompt
            }
        ],
        "reasoning_effort": reasoning_effort
    }
    
    # Only add response_format if it's provided
    if response_format is not None:
        params["response_format"] = response_format
        
    # Make the API call with the appropriate parameters
    completion = client.chat.completions.create(**params)
    

    # Comment out since 'event' is not defined
    # print(event)
    
    # print(completion.model_dump_json(indent=2))
    return completion
# Out:
# StatementMeta(, d9203f8a-a3fe-461c-a791-1d49e6717b79, 14, Finished, Available, Finished)

# %% [markdown]
# ## Define inputs
#
# ## Define Example Case Study
#
# Provide an example case study showing the conversion of ASC_VIP_Premium Ab Initio workflow to PySpark, including:
# - Input/Output schema definitions
# - Transformation functions
# - Pipeline assembly
# - Data validation

# %%
example_case_studies="""
### START EXAMPLE CASE STUDY

**Converting the ASC_VIP_Premium Ab Initio Workflow to PySpark**

Below is a complete walkthrough showing how to translate the Ab Initio *ASC_VIP_Premium* workflow (defined in a `.xfr` transform) into an equivalent, modular PySpark pipeline.
The pipeline reads source data, applies every business rule, and writes an output DataFrame that matches the required layout.

---

## 1 Input Data Schema and Loading

We start by defining the schema described in `simple_input_layout.txt`.
All original fields are `hive_string_t`, so we map them to `StringType` in Spark:

```python
from pyspark.sql.types import StructType, StructField, StringType

input_schema = StructType([
    StructField("messageid",             StringType(), True),
    StructField("agreementid",           StringType(), True),
    StructField("systementcd",           StringType(), True),
    StructField("sourcesystementcd",     StringType(), True),
    StructField("transactionuserid",     StringType(), True),
    StructField("transactioneffdttime",  StringType(), True),
    StructField("transactiontypeentcd",  StringType(), True),
    StructField("transactionprocesseddttimestr", StringType(), True),
    StructField("policynbr",             StringType(), True),
    StructField("policyversionnbr",      StringType(), True),
    StructField("premiumTypeEntCd",      StringType(), True),
    StructField("contracttermexpdttimestr", StringType(), True),
    StructField("contracttermlengthcnt", StringType(), True),
    StructField("contracttermeffdttime", StringType(), True),
    StructField("downPaymentAmtStr",     StringType(), True),
    StructField("downPaymentPct",        StringType(), True),
    StructField("downPaymentPctStr",     StringType(), True),
    StructField("accountingcompanyentcd",StringType(), True),
    StructField("stateproventcd",        StringType(), True),
    StructField("coverageentcd",         StringType(), True),
    StructField("coverageeffdttimestr",  StringType(), True),
    StructField("postalcode",            StringType(), True),
    StructField("fiscalperiod",          StringType(), True),
    StructField("peroccurrencelimitamtstr", StringType(), True),
    StructField("totalpremiumamtstr",    StringType(), True),
    StructField("fipscountyentcd",       StringType(), True),
    StructField("allstatecountycd",      StringType(), True),
    StructField("cityname",              StringType(), True),
    StructField("policystatusentcd",     StringType(), True),
    StructField("policyterminatedentcd", StringType(), True),
    StructField("netchangeamt",          StringType(), True),
    StructField("recordtype",            StringType(), True),
    StructField("batchid",               StringType(), True),
    StructField("rawfilename",           StringType(), True),
    StructField("recordsequenceid",      StringType(), True),
    StructField("accountingyear",        StringType(), True),
    StructField("accountingmonth",       StringType(), True)
])

df_input = (
    spark.read.format("csv")
    .schema(input_schema)
    .option("header", "false")
    .load("/path/to/ASC_VIP_Premium_input_data")
)
```

*(In production you may load from Hive or Parquet; keeping everything as strings preserves fidelity with the Ab Initio types.)*

---

## 2 Transformation Functions

### 2.1 Company Number Mapping

```python
import pyspark.sql.functions as F

COMPANY_MAP = {
    10:  "0031",  27:  "1585",  20:  "0025",  21:  "0776",  22:  "0002",
    60:  "0520",  63:  "0467",  64:  "0067",  65:  "0458",  68:  "1305",
    70:  "0420",  85:  "0517",  95:  "0522",  330: "1481",  270: "0192",
    339: "1437",  365: "1534",  382: "1546",  383: "1545",  357: "1562",
    359: "1564",  360: "1560",  361: "1561",  367: "1563",  387: "2206",
    386: "2207"
}
DEFAULT_COMPANY = "1481"

def add_companynumber(df):
    return df.withColumn(
        "companynumber",
        F.coalesce(
            F.expr(
                "CASE CAST(accountingcompanyentcd AS INT) " +
                " ".join([f"WHEN {k} THEN '{v}'" for k, v in COMPANY_MAP.items()]) +
                " END"
            ),
            F.lit(DEFAULT_COMPANY)
        )
    )
```

### 2.2 Policy Term Calculation

```python
from pyspark.sql.functions import year, month, to_timestamp, lit, lpad

def add_policyterm(df):
    df = (
        df.withColumn("trans_eff_dt", to_timestamp("transactioneffdttime"))
          .withColumn("term_exp_dt",  to_timestamp("contracttermexpdttimestr"))
          .withColumn("term_eff_dt",  to_timestamp("contracttermeffdttime"))
          .withColumn(
              "month_diff",
              (year("term_exp_dt") - year("trans_eff_dt")) * 12 +
              (month("term_exp_dt") - month("trans_eff_dt"))
          )
    )

    cond_newbiz          = F.col("transactiontypeentcd") == lit("0001")
    cond_endorse_nonzero = F.col("transactiontypeentcd").isin("0002", "0010") & (F.col("month_diff") != 0)
    cond_endorse_zero    = F.col("transactiontypeentcd").isin("0002", "0010") & (F.col("month_diff") == 0)
    cond_cancel          = F.col("transactiontypeentcd").isin("0004", "0012")
    cond_cancel_sameDay  = cond_cancel & (F.to_date("trans_eff_dt") == F.to_date("term_eff_dt"))
    cond_cancel_ge12     = cond_cancel & (F.col("month_diff") >= 12)
    cond_cancel_le1      = cond_cancel & (F.col("month_diff") <= 1)

    df = df.withColumn(
        "policyterm",
        F.when(cond_newbiz, lpad("contracttermlengthcnt", 2, "0"))
         .when(cond_endorse_nonzero, lpad(F.col("month_diff").cast("string"), 2, "0"))
         .when(cond_endorse_zero,    lit("01"))
         .when(cond_cancel_sameDay,  lpad("contracttermlengthcnt", 2, "0"))
         .when(cond_cancel_ge12,     lit("11"))
         .when(cond_cancel_le1,      lit("01"))
         .when(cond_cancel,          lpad(F.col("month_diff").cast("string"), 2, "0"))
         .otherwise(lpad("contracttermlengthcnt", 2, "0"))
    )

    return df.drop("trans_eff_dt", "term_exp_dt", "term_eff_dt", "month_diff")
```

### 2.3 Policy Effective Year

```python
def add_policyeffectiveyear(df):
    df = (
        df.withColumn("trans_eff_date",      to_timestamp("transactioneffdttime"))
          .withColumn("policy_term_eff_date", to_timestamp("contracttermeffdttime"))
    )

    cond_endorse    = F.col("transactiontypeentcd") == lit("0002")
    cond_cancel_mid = (
        F.col("transactiontypeentcd").isin("0004", "0012") &
        (F.to_date("trans_eff_date") != F.to_date("policy_term_eff_date"))
    )

    df = df.withColumn(
        "policyeffectiveyear",
        F.when(cond_endorse | cond_cancel_mid, F.date_format("trans_eff_date", "yyyy"))
         .otherwise(F.date_format("policy_term_eff_date", "yyyy"))
    )

    return df.drop("trans_eff_date", "policy_term_eff_date")
```

### 2.4 Classification Code Mapping

```python
def add_classificationcode(df):
    cov   = F.col("coverageentcd").cast("int")
    state = F.col("stateproventcd")

    df = df.withColumn(
        "classificationcode",
        F.when((state != "NY") & (cov == 317), "722000")
         .when((state != "NY") & (cov == 318), "709700")
         .when((state != "NY") & (cov == 319), "721000")
         .when((state != "NY") & (cov == 320), "751300")
         .when((state != "NY") & (cov == 321), "751500")
         .when((state != "NY") & (cov == 322), "799900")
         .when((state != "NY") & (cov == 323), "714400")
         .when((state != "NY") & (cov == 324), "714200")
         .when((state != "NY") & (cov == 325), "717700")
         .when((state == "NY") & (cov == 317), "703200")
         .when((state == "NY") & (cov == 319), "705100")
         .otherwise("")
    )
    return df
```

### 2.5 Miscellaneous Constant / Simple Fields

```python
from datetime import datetime

def add_misc_fields(df, filing_version="1.0"):
    run_ts = datetime.now().strftime("%Y-%m-%d%H:%M:%S")

    return (
        df
        .withColumn("lineofbusinesscode",  F.lit("06"))
        .withColumn("statecode",           F.col("stateproventcd"))
        .withColumn(
            "callyear",
            F.when(F.col("accountingyear").cast("int").isNotNull(),
                   (F.col("accountingyear").cast("int") + 1).cast("string"))
             .otherwise(F.lit(""))
        )
        .withColumn("experienceperiodyear", F.lit("0000"))
        .withColumn("experienceperiodmonth",F.lit("00"))
        .withColumn("experienceperiodday",  F.lit("00"))
        .withColumn("typeoflosscode",       F.lit("00"))
        .withColumn("annualstatementlobcd", F.lit("091"))
        .withColumn("policyidentification", F.lit("10"))
        .withColumn("claimantidentifier",   F.lit("000"))
        .withColumn("claimidentifier",      F.lit("0"*15))
        .withColumn("writtenpremium",
                    F.when(F.length("netchangeamt") > 0, F.col("netchangeamt"))
                     .otherwise(F.lit("0")))
        .withColumn("paidlosses",           F.lit("0"*12))
        .withColumn("paidclaims",           F.lit("0"*12))
        .withColumn("outstandinglosses",    F.lit("0"*12))
        .withColumn("outstandingclaims",    F.lit("0"*12))
        .withColumn("filingtype",           F.lit("PREMIUM"))
        .withColumn("filingruntimestamp",   F.lit(run_ts))
        .withColumn("filingsversion",       F.lit(filing_version))
    )
```

---

## 3 End-to-End Pipeline Assembly

```python
df_transformed = df_input
df_transformed = add_companynumber(df_transformed)
df_transformed = add_policyterm(df_transformed)
df_transformed = add_policyeffectiveyear(df_transformed)
df_transformed = add_classificationcode(df_transformed)
df_transformed = add_misc_fields(df_transformed, filing_version="1.0")
```

### Select Final Output Columns

```python
df_output = df_transformed.select(
    "messageid", "agreementid", "companynumber", "lineofbusinesscode", "statecode",
    "callyear", "experienceperiodyear", "experienceperiodmonth", "experienceperiodday",
    "classificationcode", "typeoflosscode", "policyeffectiveyear",
    "annualstatementlobcd", "policyidentification", "policyterm",
    "claimantidentifier", "claimidentifier", "writtenpremium",
    "paidlosses", "paidclaims", "outstandinglosses", "outstandingclaims",
    "policynbr", "recordsequenceid", "policyversionnbr", "coverageentcd",
    "transactiontypeentcd", "recordtype", "filingtype", "filingruntimestamp",
    "filingsversion", "accountingyear", "accountingmonth"
)
```

---

## 4 Writing the Output

```python
# As Parquet
df_output.write.mode("overwrite").parquet("/path/to/output/ASC_VIP_Premium_transformed.parquet")

# Or as a Hive table
df_output.write.mode("overwrite").saveAsTable("prod.asc_vip_premium_output")
```

The resulting Parquet files (or Hive table) exactly match the required output schema while implementing every business rule from the original Ab Initio workflow in PySpark.

### END EXAMPLE CASE STUDY
"""
# Out:
# StatementMeta(, d9203f8a-a3fe-461c-a791-1d49e6717b79, 15, Finished, Available, Finished)

# %%
#### ATTENTION: AI-generated code can include errors or operations you didn't intend. Review the code in this cell carefully before running it.

# ---------------------------------------------
# Imports
# ---------------------------------------------
import os

# Fabric puts mssparkutils under notebookutils
try:
    from notebookutils import mssparkutils  # ✅ Fabric/Synapse import path
except ImportError:
    # In the very rare case the runtime exposes it top‑level
    import mssparkutils

# ---------------------------------------------
# Paths
# ---------------------------------------------
file_prefix = "file:/lakehouse/default/"  # file prefix for absolute path

files = {
    "xfr"   : f"{file_prefix}Files/code-conversion-data/Complex/PersonalAuto_Premium_iFiling.xfr",
    "input" : f"{file_prefix}Files/code-conversion-data/Complex/complex_input_layout.txt",
    "output": f"{file_prefix}Files/code-conversion-data/Complex/complex_output_layout.txt",
}

# ---------------------------------------------
# Helper to read a small/medium text file
# ---------------------------------------------
def read_text(path: str) -> str:
    # Spark returns a single‑column DataFrame named “value” (or _c0 on older runtimes)
    return "\n".join(r[0] for r in spark.read.text(path).collect())

# ---------------------------------------------
# Load the three files
# ---------------------------------------------
try:
    xfr_content           = read_text(files["xfr"])
    input_layout_content  = read_text(files["input"])
    output_layout_content = read_text(files["output"])

    print("✅ Files read successfully!")
    print(f"  • XFR file:      {len(xfr_content):,} characters")
    print(f"  • Input layout:  {len(input_layout_content):,} characters")
    print(f"  • Output layout: {len(output_layout_content):,} characters")

except Exception as err:
    print(f"⚠️  Error reading files with Spark: {err}")
    # Optional quick existence check with mssparkutils
    for label, full_onelake in files.items():
        print(f"  • {label:<6}: {'FOUND' if mssparkutils.fs.exists(full_onelake) else 'NOT FOUND'}  → {full_onelake}")
    raise  # stops execution so downstream vars are not undefined
# Out:
# StatementMeta(, d9203f8a-a3fe-461c-a791-1d49e6717b79, 16, Finished, Available, Finished)
# ✅ Files read successfully!
#   • XFR file:      154,260 characters
#   • Input layout:  7,138 characters
#   • Output layout: 3,264 characters

# %%
scenario=f"""

You are a data engineer with expertise in Ab Initio and PySpark.

Convert the following Ab Initio XFR transformation logic into reusable PySpark functions. 
Convert this to modular PySpark code suitable for Databricks.
Also create an end-to-end Spark DataFrame pipeline that reads input using the input layout, 
applies the logic, and outputs a DataFrame matching the output layout.

The final result will be a complete PySpark workflow that reads 
the input data, applies all the business rules, and writes the output, tailored for execution in Databricks.
Provide the explanation for each step.

**Strict output rules**  
• Return **one complete Python code block** and **nothing else** (no prose, no headings).  
• All explanations must appear as inline comments inside that code block.  
• The script must:  
   1. Define reusable PySpark functions that replicate every XFR rule.  
   2. Build an end-to-end DataFrame pipeline that:  
      a. Reads data using the *Input Layout* schema.  
      b. Applies all business-rule functions.  
      c. Selects/renames columns to match the *Output Layout*.  
      d. Writes the final DataFrame (Parquet or table) for Databricks jobs.  
• No extra commentary outside the code fence.

=== Input Layout ===
{input_layout_content}

=== Output Layout ===
{output_layout_content}

=== XFR Logic ===
{xfr_content}

=== Example ===
Example case study is:
{example_case_studies}

================================================================
Produce only the PySpark script:
```python
# (model inserts the complete Databricks-ready PySpark code with inline comments)
"""
# Out:
# StatementMeta(, d9203f8a-a3fe-461c-a791-1d49e6717b79, 17, Finished, Available, Finished)

# %%
# Instructions for Ab Initio to PySpark conversion:
# 1. Extract transformations and business rules from Ab Initio .xfr and HTML report
# 2. Convert each sub-model into modular PySpark functions
# 3. Create complete PySpark workflow for Databricks execution
# 4. Provide PySpark code with explanations for each step

# %%
print(scenario)
# Out:
# StatementMeta(, 86022f1e-6446-40c9-84dc-198bd42ff73c, 57, Finished, Available, Finished)
# You are a data engineer with expertise in Ab Initio and PySpark.
#
# Convert the following Ab Initio XFR transformation logic into reusable PySpark functions.
# Convert this to modular PySpark code suitable for Databricks.
# Also create an end-to-end Spark DataFrame pipeline that reads input using the input layout,
# applies the logic, and outputs a DataFrame matching the output layout.
#
# The final result will be a complete PySpark workflow that reads
# the input data, applies all the business rules, and writes the output, tailored for execution in Databricks.
# Provide the explanation for each step.
#
# **Strict output rules**
# • Return **one complete Python code block** and **nothing else** (no prose, no headings).
# • All explanations must appear as inline comments inside that code block.
# • The script must:
#    1. Define reusable PySpark functions that replicate every XFR rule.
#    2. Build an end-to-end DataFrame pipeline that:
#       a. Reads data using the *Input Layout* schema.
#       b. Applies all business-rule functions.
#       c. Selects/renames columns to match the *Output Layout*.
#       d. Writes the final DataFrame (Parquet or table) for Databricks jobs.
# • No extra commentary outside the code fence.
#
# === Input Layout ===
# include "/~ab_home/include/hive-types.dml";
#
# type hive_row_t =
# record
#   hive_string_t policynbr = NULL;
#   hive_string_t messageid = NULL;
#   hive_string_t agreement_id = NULL;
#   hive_string_t assetid = NULL;
#   hive_string_t vehicle_id = NULL;
#   hive_string_t productentcd = NULL;
#   hive_string_t accidentforgivenessentcd = NULL;
#   hive_string_t accountingcompanyentcd = NULL;
#   hive_string_t contracttermeffdttimestr = NULL;
#   hive_string_t contracttermexpdttimestr = NULL;
#   hive_string_t contracttermlengthcnt = NULL;
#   hive_string_t lobentcd = NULL;
#   hive_string_t policytermentcd = NULL;
#   hive_string_t policyversionnbr = NULL;
#   hive_string_t renewalcnt = NULL;
#   hive_string_t stateproventcd = NULL;
#   hive_string_t coverageentcd = NULL;
#   hive_string_t vehicleuseentcd = NULL;
#   hive_string_t policy_coverageentcd = NULL;
#   hive_string_t policytelematicsscore_qualifiedoperatorcnt = NULL;
#   hive_string_t drivingscore = NULL;
#   hive_string_t contractissuedchannelentcd = NULL;
#   hive_string_t sourcesystementcd = NULL;
#   record
#     hive_string_t participantid = NULL;
#     hive_string_t birthdtstr = NULL;
#     hive_string_t genderentcd = NULL;
#     hive_string_t maritalstatusentcd = NULL;
#     hive_string_t agreementparticipantroleentcd = NULL;
#     hive_string_t drivertypeentcd = NULL;
#     hive_string_t licenseddtstr = NULL;
#     hive_string_t trainingcourseentcd = NULL;
#   end[big endian integer(4)] participants = NULL;
#   hive_string_t participantid1 = NULL;                     /*youngest male driver */
#   hive_string_t birthdtstr1 = NULL;                        /*youngest male driver */
#   hive_string_t genderentcd1 = NULL;                       /*youngest male driver */
#   hive_string_t maritalstatusentcd1 = NULL;                /*youngest male driver */
#   hive_string_t agreementparticipantroleentcd1 = NULL;     /*youngest male driver */
#   hive_string_t participantid2 = NULL;                     /*oldest driver */
#   hive_string_t birthdtstr2 = NULL;                        /*oldest driver */
#   hive_string_t genderentcd2 = NULL;                       /*oldest driver */
#   hive_string_t maritalstatusentcd2 = NULL;                /*oldest driver */
#   hive_string_t agreementparticipantroleentcd2 = NULL;     /*oldest driver */
#   hive_string_t participantid3 = NULL;                     /*youngest driver */
#   hive_string_t birthdtstr3 = NULL;                        /*youngest driver */
#   hive_string_t genderentcd3 = NULL;                       /*youngest driver */
#   hive_string_t maritalstatusentcd3 = NULL;                /*youngest driver */
#   hive_string_t agreementparticipantroleentcd3 = NULL;     /*youngest driver */
#   hive_string_t ratedparticipantid = NULL;                 /*Rated driver */
#   hive_string_t ratedbirthdtstr = NULL;                    /*Rated driver */
#   hive_string_t ratedgenderentcd = NULL;                   /*Rated driver */
#   hive_string_t ratedmaritalstatusentcd = NULL;            /*Rated driver */
#   hive_string_t rateddrivertypeentcd = NULL;               /*Rated driver */
#   hive_string_t ratedagreementparticipantroleentcd = NULL; /*Rated driver */
#   hive_string_t vehicletypeentcd = NULL;
#   hive_string_t numberofvehiclesunderpolicy = NULL;
#   hive_string_t vehicleyearmakemodel_makeentcd = NULL;
#   hive_string_t vehicleyearmakemodel_modelname = NULL;
#   hive_string_t vehicleyearmakemodel_modelyear = NULL;
#   hive_string_t vehiclevaluations_sourceentcd = NULL;
#   hive_string_t vehiclevaluations_vehiclevalueamt  = NULL;
#   hive_string_t ratingtypeentcd = NULL;
#   hive_string_t pccoverage_id = NULL;
#   hive_string_t calculatedannualmileagecnt = NULL;
#   hive_string_t combinedcoverageentcd = NULL;
#   hive_string_t vechicle_stateproventcd = NULL;
#   hive_string_t postalcode = NULL;
#   hive_string_t countyentcd = NULL;
#   hive_string_t cityname = NULL;
#   hive_string_t peroccurrencedeductibleamt = NULL;
#   hive_string_t peroccurrencedeductiblepct = NULL;
#   hive_string_t peroccurrencelimitamt = NULL;
#   hive_string_t peroccurrencelimitpct = NULL;
#   hive_string_t perpersonlimitamt = NULL;
#   hive_string_t perpersonlimitpct = NULL;
#   hive_string_t currenttermamt = NULL;
#   hive_string_t netchangeamt = NULL;
#   hive_string_t offsetamt = NULL;
#   hive_string_t onsetamt = NULL;
#   hive_string_t premiumtypeentcd = NULL;
#   hive_string_t writtenexposure = NULL;
#   hive_string_t writtenamt = NULL;
#   hive_string_t run_date = NULL;
#   hive_string_t effdttimestr = NULL;
#   hive_string_t transactiontypeentcd = NULL;
#   hive_string_t transactioneffdttimestr = NULL;
#   hive_string_t transactionprocesseddttimestr = NULL;
#   hive_string_t transactionefftermdttimestr = NULL;
#   hive_string_t numberofdefensivediscount = NULL;
#   hive_string_t changetypeentcd = NULL;
#   hive_string_t updchangetypeentcd = NULL;
#   hive_string_t policystatusentcd = NULL;
#   hive_string_t policyterminatedentcd = NULL;
#   hive_string_t airbaglocationentcd = NULL;
#   hive_string_t seatbeltfeaturetypeentcd = NULL;
#   hive_string_t[big endian integer(4)] vehicle_airbaglocationentcd = NULL;
#   hive_string_t[big endian integer(4)] vehicle_seatbeltfeaturetypeentcd = NULL;
#   hive_string_t originalnewbusinessdtstr = NULL;
#   hive_string_t numberofmajorconvictions = NULL;
#   hive_string_t numberofminorconvictions = NULL;
#   hive_string_t fullvin = NULL;
#   record
#     hive_string_t discount_id = NULL;
#     hive_string_t vehiclepolicy_id = NULL;
#     hive_string_t discountentcd = NULL;
#     hive_string_t discountamt = NULL;
#     hive_string_t discountamountpct = NULL;
#     hive_string_t discountlevelentcd = NULL;
#   end[big endian integer(4)] discount = NULL;
#   hive_string_t transactionuserid = NULL;
#   hive_string_t ifpoverrideagreement_id = NULL;
#   hive_string_t ifpoverrideassetid = NULL;
#   hive_string_t ifpoverridecoverageentcd = NULL;
#   hive_string_t[big endian integer(4)] vehicle_coverageentcd = NULL;
#   hive_string_t[big endian integer(4)] vehiclesecuritysystemfeaturetypeentcd = NULL;
#   record
#     hive_string_t optiontypeentcd = NULL;
#     hive_string_t selectedoptionvalueentcd = NULL;
#   end[big endian integer(4)] options = NULL;
#   hive_string_t businessactivityentcd = NULL;
#   hive_string_t cededtoreinsurancefacilityind = NULL;   /* Subline Exception source field placeholder*/
#   hive_string_t driverexclusionendorsementind = NULL;   /* Subline Exception source field placeholder*/
#   hive_string_t consenttorateind = NULL;                /* Subline Exception source field placeholder*/
#   record
#     hive_string_t subcoverageentcd = NULL;
#     hive_string_t subcoverage_id = NULL;
#     hive_string_t peroccurrencelimitamt = NULL;
#     hive_string_t peroccurrencelimitpct = NULL;
#     hive_string_t perpersonlimitamt = NULL;
#     hive_string_t perpersonlimitpct = NULL;
#     hive_string_t combinedcoverageentcd = NULL;
#   end[big endian integer(4)] subcoverage = NULL;
#   hive_string_t batchid = NULL;
#   hive_string_t recordsequenceid = NULL;
#   hive_string_t accountingyear = NULL;
#   hive_string_t accountingmonth = NULL;
#   int hive_to_dml_version() = 4;
# end;
# metadata type = hive_row_t;
#
#
#
# Note:
# hive_string_t = string(big endian integer(4), charset="utf-8")
#
# === Output Layout ===
# record
#   hive_string_t statisticalstateproventcd = NULL;
#   hive_string_t companynumber = NULL;
#   hive_string_t lineofbusinesscode = NULL;
#   hive_string_t statecode = NULL;
#   hive_string_t callyear = NULL;
#   hive_string_t accountingquarter = NULL;
#   hive_string_t experienceperiodyear = NULL;
#   hive_string_t experienceperiodmonth = NULL;
#   hive_string_t experienceperiodday = NULL;
#   hive_string_t coveragecode = NULL;
#   hive_string_t classificationcode = NULL;
#   hive_string_t typeoflosscode = NULL;
#   hive_string_t territorycode = NULL;
#   hive_string_t zipcode = NULL;
#   hive_string_t policyeffectiveyear = NULL;
#   hive_string_t stateexceptioncode = NULL;
#   hive_string_t annualstatementlobcd = NULL;
#   hive_string_t deductibleindicatorcode = NULL;
#   hive_string_t deductibleamount = NULL;
#   hive_string_t sublinecode = NULL;
#   hive_string_t manufacturersmodelyear = NULL;
#   hive_string_t agegroupcode = NULL;
#   hive_string_t antitheftcode = NULL;
#   hive_string_t daytimerunninglampcode = NULL;
#   hive_string_t defensivedrivercode = NULL;
#   hive_string_t exceptionbcode = NULL;
#   hive_string_t gendercode = NULL;
#   hive_string_t policyterm = NULL;
#   hive_string_t penaltypoints = NULL;
#   hive_string_t policylowerlimit = NULL;
#   hive_string_t policyupperlimit = NULL;
#   hive_string_t symbolcode = NULL;
#   hive_string_t policyidcode = NULL;
#   hive_string_t passiverestraintcode = NULL;
#   hive_string_t ratingzonecode = NULL;
#   hive_string_t terminalzonecode = NULL;
#   hive_string_t forgivenesscode = NULL;
#   hive_string_t claimidentifier = NULL;
#   hive_string_t claimantidentifier = NULL;
#   hive_string_t writtenexposure = NULL;
#   hive_string_t writtenpremium = NULL;
#   hive_string_t paidlosses = NULL;
#   hive_string_t paidclaims = NULL;
#   hive_string_t paidallocatedlossadjustmentexpense = NULL;
#   hive_string_t outstandinglosses = NULL;
#   hive_string_t outstandingclaims = NULL;
#   hive_string_t outstandingallocatedlossadjexp = NULL;
#   hive_string_t policynbr = NULL;
#   hive_string_t messageid = NULL;
#   hive_string_t agreement_id = NULL;
#   hive_string_t coverageentcd = NULL;
#   hive_string_t assetid = NULL;
#   hive_string_t transactiontypeentcd = NULL;
#   hive_string_t premiumtypeentcd = NULL;
#   hive_string_t changetypeentcd = NULL;
#   hive_string_t ifpoverrideagreement_id = NULL;
#   hive_string_t ifpoverrideassetid = NULL;
#   hive_string_t ifpoverridecoverageentcd = NULL;
#   hive_string_t limitcode = NULL;
#   hive_string_t recordsequenceid = NULL;
#   hive_string_t filingtype = NULL;
#   hive_string_t filingruntimestamp = NULL;
#   hive_string_t filingrulesversion = NULL;
#   hive_string_t accountingyear = NULL;
#   hive_string_t accountingmonth = NULL;
#   hive_string_t claimparticipant_refid = NULL;
#   hive_string_t claimstateproventcd = NULL;
#   hive_string_t accountingcompanyentcd = NULL;
#   hive_string_t contracttermeffdttimestr = NULL;
#   hive_string_t contracttermexpdttimestr = NULL;
#   hive_string_t transactioneffdttimestr = NULL;
#   hive_string_t agemaledriver = NULL;
#   hive_string_t ageyoungestdriver = NULL;
#   hive_string_t ageoldestdriver = NULL;
#   hive_string_t claimstatusentcd = NULL;
#   hive_string_t alpha_coverage_cd = NULL;
#   hive_string_t coverageclaimantsid = NULL;
#   hive_string_t claimcoverageentcd = NULL;
#   int hive_to_dml_version() = 4;
# end;
#
# === XFR Logic ===
# /*   Do not edit. Generated file - BRE 4.1.5.7;/Projects/ent/ess/direct_state_reporting/rset/PersonalAuto_Premium_iFiling/ruleset.rset;Default deployment;   */
#
#
# /*@ BizHidden:true @*/
# /*   lookup ASC Adhoc Discount Lookup   */
# out0::bzt_63_ac3802b_5fad2312_27901_0(in0,in1,in2,in3,in4)=
# begin
# let record
#   string(",") fiscalYrMo, policyNbr, agreementId, assetId, messageId, stateProvEntCd, vehicleId, discountEntCd;
#   decimal("\r\n") returnCd;
# end __bzt_local_res__;
# __bzt_local_res__ = fail_if_error(lookup("ASC Adhoc Discount Lookup",in0,in1,in2,in3,in4));
#   out0::__bzt_local_res__;
# end;
#
#
# /*@ BizHidden:true @*/
# /*   lookup ASC Adhoc Discount Lookup   */
# out0::bzt_60_ac3802b_5fad2312_27901_0(in0,in1,in2,in3,in4)=
# begin
# let record
#   string(",") fiscalYrMo, policyNbr, agreementId, assetId, messageId, stateProvEntCd, vehicleId, discountEntCd;
#   decimal("\r\n") returnCd;
# end __bzt_local_res__;
# __bzt_local_res__ = fail_if_error(lookup("ASC Adhoc Discount Lookup",in0,in1,in2,in3,in4));
#   out0::__bzt_local_res__;
# end;
#
#
# /*@ BizHidden:true @*/
# /*   lookup Dynamic Config Profile   */
# out0::bzt_76_ac3802b_5fad2312_27901_0(in0,in1,in2)=
# begin
# let record
#   string("\t") DCP_CONFIG_IND, DCP_ATTRIBUTE_CD, DCP_ATTRIBUTE_NM, DCP_ATTRIBUTE_TXT;
#   decimal("\t") DCP_ATTRIBUTE_NUM;
#   string(1) newline = "\n";
# end __bzt_local_res__;
# __bzt_local_res__ = fail_if_error(lookup("Dynamic Config Profile",in0,in1,in2));
#   out0::__bzt_local_res__;
# end;
#
#
# /*@ BizHidden:true @*/
# /*   lookup ISO State Code   */
# out0::bzt_98_ac3802b_5fad2312_27901_0(in0)=
# begin
# let record
#   string("\t") country_code, policy_state_code = NULL(''), policy_state_alpha_code, policy_iso_state_code, claim_nextgen_state_code;
#   string("\n") claim_tico_state_code;
# end __bzt_local_res__;
# __bzt_local_res__ = fail_if_error(lookup("ISO State Code",in0));
#   out0::__bzt_local_res__;
# end;
#
#
# /*@ BizHidden:true @*/
# /*   lookup Territory Code   */
# out0::bzt_77_ac3802b_5fad2312_27901_0(in0)=
# begin
# let record
#   string("\t") state_zipcodes_regex;
#   string("\n") territory_code;
# end __bzt_local_res__;
# __bzt_local_res__ = fail_if_error(lookup("Territory Code",in0));
#   out0::__bzt_local_res__;
# end;
#
#
# /*@ BizHidden:true @*/
# /*   lookup Territory Code   */
# out0::bzt_47_ac3802b_5fad2312_27901_0(in0)=
# begin
# let record
#   string("\t") state_zipcodes_regex;
#   string("\n") territory_code;
# end __bzt_local_res__;
# __bzt_local_res__ = fail_if_error(lookup("Territory Code",in0));
#   out0::__bzt_local_res__;
# end;
# let unsigned long bzt_79_ac3802b_5fad2312_27901_0 = 0;
# let int bzt_80_ac3802b_5fad2312_27901_0 = 0;
# let int bzt_83_ac3802b_5fad2312_27901_0 = 0;
# let unsigned long bzt_122_ac3802b_5fad2312_27901_0 = 0;
#
# /*@ BizHidden:true @*/
# out0::bzt_100_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_79_ac3802b_5fad2312_27901_0 & 67108864))begin
#   if(first_defined(fail_if_error(in0.stateproventcd  member  [vector 'FL','CT']),0))
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 134217728;
#   bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 67108864;
# end
#   out0::bzt_79_ac3802b_5fad2312_27901_0 & 134217728;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_101_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_79_ac3802b_5fad2312_27901_0 & 268435456))begin
#   if(first_defined(fail_if_error(in0.stateproventcd  member  [vector 'NJ','PA']),0))
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 536870912;
#   bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 268435456;
# end
#   out0::bzt_79_ac3802b_5fad2312_27901_0 & 536870912;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_102_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_79_ac3802b_5fad2312_27901_0 & 1073741824))begin
#   if(first_defined(fail_if_error(in0.airbaglocationentcd  member  [vector '0003','0007','0011']),0))
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 2147483648;
#   bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 1073741824;
# end
#   out0::bzt_79_ac3802b_5fad2312_27901_0 & 2147483648;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_103_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_79_ac3802b_5fad2312_27901_0 & 4294967296))begin
#   if(first_defined(fail_if_error(in0.airbaglocationentcd  member  [vector '0001','0002','0004','0005','0008']),0))
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 8589934592;
#   bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 4294967296;
# end
#   out0::bzt_79_ac3802b_5fad2312_27901_0 & 8589934592;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_104_ac3802b_5fad2312_27901_0(in0) inline =
# begin
# let long __bzt_co__  not NULL = first_defined(fail_if_error(in0.stateproventcd =='FL'),0);
#   if( __bzt_co__ )
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 17179869184;
#   out0:: __bzt_co__ ;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_105_ac3802b_5fad2312_27901_0(in0) inline =
# begin
# let long __bzt_co__  not NULL = first_defined(fail_if_error(in0.stateproventcd =='HI'),0);
#   if( __bzt_co__ )
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 34359738368;
#   out0:: __bzt_co__ ;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_106_ac3802b_5fad2312_27901_0(in0) inline =
# begin
# let long __bzt_co__  not NULL = first_defined(fail_if_error(in0.stateproventcd =="MT"),0);
#   if( __bzt_co__ )
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 68719476736;
#   out0:: __bzt_co__ ;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_107_ac3802b_5fad2312_27901_0(in0) inline =
# begin
# let long __bzt_co__  not NULL = first_defined(fail_if_error(in0.stateproventcd =="SC"),0);
#   if( __bzt_co__ )
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 137438953472;
#   out0:: __bzt_co__ ;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_108_ac3802b_5fad2312_27901_0(in0) inline =
# begin
# let long __bzt_co__  not NULL = first_defined(fail_if_error(in0.stateproventcd =="RI"),0);
#   if( __bzt_co__ )
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 274877906944;
#   out0:: __bzt_co__ ;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_109_ac3802b_5fad2312_27901_0(in0) inline =
# begin
# let long __bzt_co__  not NULL = first_defined(fail_if_error(in0.stateproventcd =="PA"),0);
#   if( __bzt_co__ )
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 549755813888;
#   out0:: __bzt_co__ ;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_10_ac3802b_5fad2312_27901_0(in0)=
# begin
# /*   extract_if   */
# let long bzt_2 not NULL = 0;
#
#   out0::for(bzt_2,bzt_2<first_defined(length_of(in0),0)):
#           if(first_defined(fail_if_error(in0[bzt_2].discountentcd =='0077'),0))
#             in0[bzt_2].discountentcd;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_110_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_79_ac3802b_5fad2312_27901_0 & 1099511627776))begin
#   if(first_defined(fail_if_error(! in0.maritalstatusentcd2  member  [vector '0001','0004']),0))
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 2199023255552;
#   bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 1099511627776;
# end
#   out0::bzt_79_ac3802b_5fad2312_27901_0 & 2199023255552;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_111_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_79_ac3802b_5fad2312_27901_0 & 4398046511104))begin
#   if(first_defined(fail_if_error(in0.maritalstatusentcd2  member  [vector '0001','0004']),0))
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 8796093022208;
#   bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 4398046511104;
# end
#   out0::bzt_79_ac3802b_5fad2312_27901_0 & 8796093022208;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_112_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_79_ac3802b_5fad2312_27901_0 & 17592186044416))begin
#   if(first_defined(fail_if_error(!(in0.participantid2 member [vector"0019","0086","0087"])),0))
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 35184372088832;
#   bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 17592186044416;
# end
#   out0::bzt_79_ac3802b_5fad2312_27901_0 & 35184372088832;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_113_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_79_ac3802b_5fad2312_27901_0 & 70368744177664))begin
#   if(first_defined(fail_if_error(! in0.maritalstatusentcd1  member  [vector '0001','0004']),0))
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 140737488355328;
#   bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 70368744177664;
# end
#   out0::bzt_79_ac3802b_5fad2312_27901_0 & 140737488355328;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_114_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_79_ac3802b_5fad2312_27901_0 & 281474976710656))begin
#   if(first_defined(fail_if_error(in0.maritalstatusentcd1  member  [vector '0001','0004']),0))
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 562949953421312;
#   bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 281474976710656;
# end
#   out0::bzt_79_ac3802b_5fad2312_27901_0 & 562949953421312;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_115_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_79_ac3802b_5fad2312_27901_0 & 1125899906842624))begin
#   if(first_defined(fail_if_error(!(in0.participantid1 member [vector"0019","0086","0087"])),0))
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 2251799813685248;
#   bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 1125899906842624;
# end
#   out0::bzt_79_ac3802b_5fad2312_27901_0 & 2251799813685248;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_116_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_79_ac3802b_5fad2312_27901_0 & 4503599627370496))begin
#   if(first_defined(fail_if_error(! (first_defined((decimal(''))in0.vehicleuseentcd,0000))  member  [vector 0001,0003]),0))
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 9007199254740992;
#   bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 4503599627370496;
# end
#   out0::bzt_79_ac3802b_5fad2312_27901_0 & 9007199254740992;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_117_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_79_ac3802b_5fad2312_27901_0 & 18014398509481984))begin
#   if(first_defined(fail_if_error(bzt_19_ac3802b_5fad2312_27901_0(in0.discount,'0162')),0))
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 36028797018963968;
#   bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 18014398509481984;
# end
#   out0::bzt_79_ac3802b_5fad2312_27901_0 & 36028797018963968;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_118_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_79_ac3802b_5fad2312_27901_0 & 72057594037927936))begin
#   if(first_defined(fail_if_error(in0.maritalstatusentcd1 not  member   [vector '0001','0004']),0))
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 144115188075855872;
#   bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 72057594037927936;
# end
#   out0::bzt_79_ac3802b_5fad2312_27901_0 & 144115188075855872;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_119_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_79_ac3802b_5fad2312_27901_0 & 288230376151711744))begin
#   if(first_defined(fail_if_error(! in0.maritalstatusentcd3  member  [vector '0001','0004']),0))
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 576460752303423488;
#   bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 288230376151711744;
# end
#   out0::bzt_79_ac3802b_5fad2312_27901_0 & 576460752303423488;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_120_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_79_ac3802b_5fad2312_27901_0 & 1152921504606846976))begin
#   if(first_defined(fail_if_error(in0.maritalstatusentcd3  member  [vector '0001','0004']),0))
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 2305843009213693952;
#   bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 1152921504606846976;
# end
#   out0::bzt_79_ac3802b_5fad2312_27901_0 & 2305843009213693952;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_121_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_122_ac3802b_5fad2312_27901_0 & 1))begin
#   if(first_defined(fail_if_error(in0.maritalstatusentcd3  member  [vector "0001","0004"]),0))
#     bzt_122_ac3802b_5fad2312_27901_0 = bzt_122_ac3802b_5fad2312_27901_0 | 2;
#   bzt_122_ac3802b_5fad2312_27901_0 = bzt_122_ac3802b_5fad2312_27901_0 | 1;
# end
#   out0::bzt_122_ac3802b_5fad2312_27901_0 & 2;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_123_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_122_ac3802b_5fad2312_27901_0 & 4))begin
#   if(first_defined(fail_if_error(! in0.maritalstatusentcd3  member  [vector "0001","0004"]),0))
#     bzt_122_ac3802b_5fad2312_27901_0 = bzt_122_ac3802b_5fad2312_27901_0 | 8;
#   bzt_122_ac3802b_5fad2312_27901_0 = bzt_122_ac3802b_5fad2312_27901_0 | 4;
# end
#   out0::bzt_122_ac3802b_5fad2312_27901_0 & 8;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_124_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_122_ac3802b_5fad2312_27901_0 & 16))begin
#   if(first_defined(fail_if_error(!(in0.participantid3 member [vector"0019","0086","0087"])),0))
#     bzt_122_ac3802b_5fad2312_27901_0 = bzt_122_ac3802b_5fad2312_27901_0 | 32;
#   bzt_122_ac3802b_5fad2312_27901_0 = bzt_122_ac3802b_5fad2312_27901_0 | 16;
# end
#   out0::bzt_122_ac3802b_5fad2312_27901_0 & 32;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_125_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_122_ac3802b_5fad2312_27901_0 & 64))begin
#   if(first_defined(fail_if_error((in0.participantid3 member [vector"0019","0042"])),0))
#     bzt_122_ac3802b_5fad2312_27901_0 = bzt_122_ac3802b_5fad2312_27901_0 | 128;
#   bzt_122_ac3802b_5fad2312_27901_0 = bzt_122_ac3802b_5fad2312_27901_0 | 64;
# end
#   out0::bzt_122_ac3802b_5fad2312_27901_0 & 128;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_126_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_122_ac3802b_5fad2312_27901_0 & 256))begin
#   if(first_defined(fail_if_error(sql_or(sql_or(((in0.participantid3!="0019") && (in0.participantid3!="0042")),is_null(in0.participantid3)),is_blank(in0.participantid3))),0))
#     bzt_122_ac3802b_5fad2312_27901_0 = bzt_122_ac3802b_5fad2312_27901_0 | 512;
#   bzt_122_ac3802b_5fad2312_27901_0 = bzt_122_ac3802b_5fad2312_27901_0 | 256;
# end
#   out0::bzt_122_ac3802b_5fad2312_27901_0 & 512;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_127_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_122_ac3802b_5fad2312_27901_0 & 1024))begin
#   if(first_defined(fail_if_error(((decimal("")) in0.coverageentcd)  member  [vector 73,182]),0))
#     bzt_122_ac3802b_5fad2312_27901_0 = bzt_122_ac3802b_5fad2312_27901_0 | 2048;
#   bzt_122_ac3802b_5fad2312_27901_0 = bzt_122_ac3802b_5fad2312_27901_0 | 1024;
# end
#   out0::bzt_122_ac3802b_5fad2312_27901_0 & 2048;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_128_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_122_ac3802b_5fad2312_27901_0 & 4096))begin
#   if(first_defined(fail_if_error(((decimal("")) in0.coverageentcd)  member  [vector 66,73,182]),0))
#     bzt_122_ac3802b_5fad2312_27901_0 = bzt_122_ac3802b_5fad2312_27901_0 | 8192;
#   bzt_122_ac3802b_5fad2312_27901_0 = bzt_122_ac3802b_5fad2312_27901_0 | 4096;
# end
#   out0::bzt_122_ac3802b_5fad2312_27901_0 & 8192;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_129_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_122_ac3802b_5fad2312_27901_0 & 16384))begin
#   if(first_defined(fail_if_error(((decimal("")) in0.coverageentcd)  member  [vector 0066,0073]),0))
#     bzt_122_ac3802b_5fad2312_27901_0 = bzt_122_ac3802b_5fad2312_27901_0 | 32768;
#   bzt_122_ac3802b_5fad2312_27901_0 = bzt_122_ac3802b_5fad2312_27901_0 | 16384;
# end
#   out0::bzt_122_ac3802b_5fad2312_27901_0 & 32768;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_19_ac3802b_5fad2312_27901_0(in0,in1)=
# begin
# /*   any_contains   */
# let int __bzt_restmp__ = 0;
# let long ub_2 not NULL = 0;
# let long bzt_2 not NULL = 0;
# begin block outer
# ub_2 = first_defined(fail_if_error(length_of(in0)),0);
# for(bzt_2,bzt_2<ub_2)begin
#   if(first_defined(fail_if_error(string_index(in0[bzt_2].discountentcd,in1 )!= 0),0))begin
#     __bzt_restmp__ = __bzt_restmp__ + 1;
#     exit outer;
#   end
# end
# end block outer
# out0:: (decimal('',0)) __bzt_restmp__;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_22_ac3802b_5fad2312_27901_0(in0)=
# begin
# /*   first_if   */
# let long ub_2 not NULL = 0;
# let long bzt_2 not NULL = 0;
# let long iv_2 not NULL = -1;
# begin block outer
# ub_2 = first_defined(fail_if_error(length_of(in0)),0);
# for(bzt_2,bzt_2<ub_2)begin
#   if(first_defined(fail_if_error(in0[bzt_2].subcoverageentcd=='0228'),0))begin
#         if((iv_2 == -1))begin
#       iv_2 = bzt_2;
#       exit outer;
#     end
#   end
# end
# end block outer
#   out0::if((iv_2!= -1))in0[iv_2].perpersonlimitamt;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_23_ac3802b_5fad2312_27901_0(in0,in1)=
# begin
# /*   any_contains   */
# let int __bzt_restmp__ = 0;
# let long ub_2 not NULL = 0;
# let long bzt_2 not NULL = 0;
# begin block outer
# ub_2 = first_defined(fail_if_error(length_of(in0)),0);
# for(bzt_2,bzt_2<ub_2)begin
#   if(first_defined(fail_if_error(string_index(in0[bzt_2].subcoverageentcd,in1)!= 0),0))begin
#     __bzt_restmp__ = __bzt_restmp__ + 1;
#     exit outer;
#   end
# end
# end block outer
# out0:: (decimal('',0)) __bzt_restmp__;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_36_ac3802b_5fad2312_27901_0(in0)=
# begin
# /*   extract_if   */
# let long bzt_2 not NULL = 0;
#
#   out0::for(bzt_2,bzt_2<first_defined(length_of(in0),0)):
#           if(first_defined(fail_if_error(in0[bzt_2].discountentcd == '0189' ),0))
#             in0[bzt_2].discountentcd;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_38_ac3802b_5fad2312_27901_0(in0)=
# begin
# /*   extract_if   */
# let long bzt_2 not NULL = 0;
#
#   out0::for(bzt_2,bzt_2<first_defined(length_of(in0),0)):
#           if(first_defined(fail_if_error(in0[bzt_2].discountentcd=='0036' ),0))
#             in0[bzt_2].discountentcd;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_3_ac3802b_5fad2312_27901_0(in0,in1)=
# begin
# /*   any_contains   */
# let int __bzt_restmp__ = 0;
# let long ub_2 not NULL = 0;
# let long bzt_2 not NULL = 0;
# begin block outer
# ub_2 = first_defined(fail_if_error(length_of(in0)),0);
# for(bzt_2,bzt_2<ub_2)begin
#   if(first_defined(fail_if_error(string_index(in0[bzt_2],in1 )!= 0),0))begin
#     __bzt_restmp__ = __bzt_restmp__ + 1;
#     exit outer;
#   end
# end
# end block outer
# out0:: (decimal('',0)) __bzt_restmp__;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_42_ac3802b_5fad2312_27901_0(in0)=
# begin
# /*   first_if   */
# let long ub_2 not NULL = 0;
# let long bzt_2 not NULL = 0;
# let long iv_2 not NULL = -1;
# begin block outer
# ub_2 = first_defined(fail_if_error(length_of(in0)),0);
# for(bzt_2,bzt_2<ub_2)begin
#   if(first_defined(fail_if_error(in0[bzt_2].optiontypeentcd=='0024'),0))begin
#         if((iv_2 == -1))begin
#       iv_2 = bzt_2;
#       exit outer;
#     end
#   end
# end
# end block outer
#   out0::if((iv_2!= -1))in0[iv_2].selectedoptionvalueentcd;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_43_ac3802b_5fad2312_27901_0(in0,in1)=
# begin
# /*   any_contains   */
# let int __bzt_restmp__ = 0;
# let long ub_2 not NULL = 0;
# let long bzt_2 not NULL = 0;
# begin block outer
# ub_2 = first_defined(fail_if_error(length_of(in0)),0);
# for(bzt_2,bzt_2<ub_2)begin
#   if(first_defined(fail_if_error(string_index(in0[bzt_2].selectedoptionvalueentcd,in1)!= 0),0))begin
#     __bzt_restmp__ = __bzt_restmp__ + 1;
#     exit outer;
#   end
# end
# end block outer
# out0:: (decimal('',0)) __bzt_restmp__;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_44_ac3802b_5fad2312_27901_0(in0,in1)=
# begin
# /*   any_contains   */
# let int __bzt_restmp__ = 0;
# let long ub_2 not NULL = 0;
# let long bzt_2 not NULL = 0;
# begin block outer
# ub_2 = first_defined(fail_if_error(length_of(in0)),0);
# for(bzt_2,bzt_2<ub_2)begin
#   if(first_defined(fail_if_error(string_index(in0[bzt_2].optiontypeentcd,in1)!= 0),0))begin
#     __bzt_restmp__ = __bzt_restmp__ + 1;
#     exit outer;
#   end
# end
# end block outer
# out0:: (decimal('',0)) __bzt_restmp__;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_45_ac3802b_5fad2312_27901_0(in0)=
# begin
# /*   first_if   */
# let long ub_2 not NULL = 0;
# let long bzt_2 not NULL = 0;
# let long iv_2 not NULL = -1;
# begin block outer
# ub_2 = first_defined(fail_if_error(length_of(in0)),0);
# for(bzt_2,bzt_2<ub_2)begin
#   if(first_defined(fail_if_error(in0[bzt_2].optiontypeentcd=='0033'),0))begin
#         if((iv_2 == -1))begin
#       iv_2 = bzt_2;
#       exit outer;
#     end
#   end
# end
# end block outer
#   out0::if((iv_2!= -1))in0[iv_2].selectedoptionvalueentcd;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_4_ac3802b_5fad2312_27901_0(in0,in1)=
# begin
# /*   any_equals_any   */
# let int __bzt_restmp__ = 0;
# let long ub_2 not NULL = 0;
# let long bzt_2 not NULL = 0;
# begin block outer
# ub_2 = first_defined(fail_if_error(length_of(in0)),0);
# for(bzt_2,bzt_2<ub_2)begin
#   if(first_defined(fail_if_error(in0[bzt_2] member in1),0))begin
#     __bzt_restmp__ = __bzt_restmp__ + 1;
#     exit outer;
#   end
# end
# end block outer
# out0:: (decimal('',0)) __bzt_restmp__;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_5_ac3802b_5fad2312_27901_0(in0)=
# begin
# /*   extract_if   */
# let long bzt_2 not NULL = 0;
#
#   out0::for(bzt_2,bzt_2<first_defined(length_of(in0),0)):
#           if(first_defined(fail_if_error(in0[bzt_2].discountentcd  member   [vector '0049','0019','0078'] ),0))
#             in0[bzt_2].discountentcd;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_6_ac3802b_5fad2312_27901_0(in0)=
# begin
# /*   first_if   */
# let long ub_2 not NULL = 0;
# let long bzt_2 not NULL = 0;
# let long iv_2 not NULL = -1;
# begin block outer
# ub_2 = first_defined(fail_if_error(length_of(in0)),0);
# for(bzt_2,bzt_2<ub_2)begin
#   if(first_defined(fail_if_error(in0[bzt_2].optiontypeentcd=='0021'),0))begin
#         if((iv_2 == -1))begin
#       iv_2 = bzt_2;
#       exit outer;
#     end
#   end
# end
# end block outer
#   out0::if((iv_2!= -1))in0[iv_2].selectedoptionvalueentcd;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_78_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_79_ac3802b_5fad2312_27901_0 & 1))begin
#   if(first_defined(fail_if_error(is_defined( in0.transactioneffdttimestr ) && !is_blank( in0.transactioneffdttimestr )),0))
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 2;
#   bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 1;
# end
#   out0::bzt_79_ac3802b_5fad2312_27901_0 & 2;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_7_ac3802b_5fad2312_27901_0(in0)=
# begin
# /*   first_if   */
# let long ub_2 not NULL = 0;
# let long bzt_2 not NULL = 0;
# let long iv_2 not NULL = -1;
# begin block outer
# ub_2 = first_defined(fail_if_error(length_of(in0)),0);
# for(bzt_2,bzt_2<ub_2)begin
#   if(first_defined(fail_if_error(in0[bzt_2].optiontypeentcd=='0040'),0))begin
#         if((iv_2 == -1))begin
#       iv_2 = bzt_2;
#       exit outer;
#     end
#   end
# end
# end block outer
#   out0::if((iv_2!= -1))in0[iv_2].selectedoptionvalueentcd;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_81_ac3802b_5fad2312_27901_0(in0) inline =
# begin
# bzt_80_ac3802b_5fad2312_27901_0 = first_defined(fail_if_error(((decimal('')) decimal_lrepad(string_suffix(in0.premiumtypeentcd,4),4,"0")) ==0009),0);
#   out0::bzt_80_ac3802b_5fad2312_27901_0;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_82_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_79_ac3802b_5fad2312_27901_0 & 4))begin
#   if(first_defined(fail_if_error(! ((decimal('')) decimal_lrepad(string_suffix(in0.coverageentcd,4),4,"0"))  member  [vector 0009,0011,0018,0027,0038,0078,0079,0085,0087,0088,9005,9033,9077]),0))
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 8;
#   bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 4;
# end
#   out0::bzt_79_ac3802b_5fad2312_27901_0 & 8;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_84_ac3802b_5fad2312_27901_0(in0) inline =
# begin
# bzt_83_ac3802b_5fad2312_27901_0 = first_defined(fail_if_error(((decimal(''))in0.transactiontypeentcd)  member  [vector 4,12]),0);
#   out0::bzt_83_ac3802b_5fad2312_27901_0;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_85_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_79_ac3802b_5fad2312_27901_0 & 16))begin
#   if(first_defined(fail_if_error(((decimal(""))first_defined(in0.perpersonlimitamt,"0")) >0 &&  ((decimal(""))first_defined(in0.perpersonlimitamt,"0")) !=(decimal('')) first_defined(in0.peroccurrencelimitamt,'0')),0))
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 32;
#   bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 16;
# end
#   out0::bzt_79_ac3802b_5fad2312_27901_0 & 32;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_86_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_79_ac3802b_5fad2312_27901_0 & 64))begin
#   if(first_defined(fail_if_error(((decimal(""))first_defined(in0.perpersonlimitamt,"0")) >0 &&  ((decimal(""))first_defined(in0.perpersonlimitamt,"0")) <=(decimal('')) first_defined(in0.peroccurrencelimitamt,'0')),0))
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 128;
#   bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 64;
# end
#   out0::bzt_79_ac3802b_5fad2312_27901_0 & 128;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_87_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_79_ac3802b_5fad2312_27901_0 & 256))begin
#   if(first_defined(fail_if_error(((decimal('')) first_defined(in0.peroccurrencelimitamt,'0')) >0 &&  ((decimal('')) first_defined(in0.peroccurrencelimitamt,'0')) <1000),0))
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 512;
#   bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 256;
# end
#   out0::bzt_79_ac3802b_5fad2312_27901_0 & 512;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_88_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_79_ac3802b_5fad2312_27901_0 & 1024))begin
#   if(first_defined(fail_if_error(((decimal('')) first_defined(in0.peroccurrencelimitamt,'0')) >=1000 &&  ((decimal('')) first_defined(in0.peroccurrencelimitamt,'0')) <10000000),0))
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 2048;
#   bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 1024;
# end
#   out0::bzt_79_ac3802b_5fad2312_27901_0 & 2048;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_89_ac3802b_5fad2312_27901_0(in0) inline =
# begin
# let long __bzt_co__  not NULL = first_defined(fail_if_error(in0.stateproventcd =="MD"),0);
#   if( __bzt_co__ )
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 4096;
#   out0:: __bzt_co__ ;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_8_ac3802b_5fad2312_27901_0(in0)=
# begin
# /*   first_if   */
# let long ub_2 not NULL = 0;
# let long bzt_2 not NULL = 0;
# let long iv_2 not NULL = -1;
# begin block outer
# ub_2 = first_defined(fail_if_error(length_of(in0)),0);
# for(bzt_2,bzt_2<ub_2)begin
#   if(first_defined(fail_if_error(in0[bzt_2].optiontypeentcd=='0020'),0))begin
#         if((iv_2 == -1))begin
#       iv_2 = bzt_2;
#       exit outer;
#     end
#   end
# end
# end block outer
#   out0::if((iv_2!= -1))in0[iv_2].selectedoptionvalueentcd;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_90_ac3802b_5fad2312_27901_0(in0) inline =
# begin
# let long __bzt_co__  not NULL = first_defined(fail_if_error(in0.stateproventcd =="PA"),0);
#   if( __bzt_co__ )
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 8192;
#   out0:: __bzt_co__ ;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_91_ac3802b_5fad2312_27901_0(in0) inline =
# begin
# let long __bzt_co__  not NULL = first_defined(fail_if_error(in0.stateproventcd =="GA"),0);
#   if( __bzt_co__ )
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 16384;
#   out0:: __bzt_co__ ;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_92_ac3802b_5fad2312_27901_0(in0) inline =
# begin
# let long __bzt_co__  not NULL = first_defined(fail_if_error(in0.stateproventcd =="MN"),0);
#   if( __bzt_co__ )
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 32768;
#   out0:: __bzt_co__ ;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_93_ac3802b_5fad2312_27901_0(in0) inline =
# begin
# let long __bzt_co__  not NULL = first_defined(fail_if_error(in0.stateproventcd =='HI'),0);
#   if( __bzt_co__ )
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 65536;
#   out0:: __bzt_co__ ;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_94_ac3802b_5fad2312_27901_0(in0) inline =
# begin
# let long __bzt_co__  not NULL = first_defined(fail_if_error(in0.stateproventcd =="FL"),0);
#   if( __bzt_co__ )
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 131072;
#   out0:: __bzt_co__ ;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_95_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_79_ac3802b_5fad2312_27901_0 & 262144))begin
#   if(first_defined(fail_if_error(((decimal(""))in0.coverageentcd)  member  [vector 0016,0043,0204,0205,0228]),0))
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 524288;
#   bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 262144;
# end
#   out0::bzt_79_ac3802b_5fad2312_27901_0 & 524288;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_96_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_79_ac3802b_5fad2312_27901_0 & 1048576))begin
#   if(first_defined(fail_if_error(((decimal(""))in0.coverageentcd)  member  [vector 0073,0077]),0))
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 2097152;
#   bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 1048576;
# end
#   out0::bzt_79_ac3802b_5fad2312_27901_0 & 2097152;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_97_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_79_ac3802b_5fad2312_27901_0 & 4194304))begin
#   if(first_defined(fail_if_error(is_defined( in0.vehicleyearmakemodel_modelyear ) && !is_blank( in0.vehicleyearmakemodel_modelyear )),0))
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 8388608;
#   bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 4194304;
# end
#   out0::bzt_79_ac3802b_5fad2312_27901_0 & 8388608;
# end;
#
#
# /*@ BizHidden:true @*/
# out0::bzt_99_ac3802b_5fad2312_27901_0(in0)=
# begin
# if(!(bzt_79_ac3802b_5fad2312_27901_0 & 16777216))begin
#   if(first_defined(fail_if_error(in0.stateproventcd  member  [vector 'DE','DC','HI','KS','MD','MN','NY','ND','OR','UT','WA']),0))
#     bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 33554432;
#   bzt_79_ac3802b_5fad2312_27901_0 = bzt_79_ac3802b_5fad2312_27901_0 | 16777216;
# end
#   out0::bzt_79_ac3802b_5fad2312_27901_0 & 33554432;
# end;
#
#
# out0::PersonalAuto_Premium_iFiling_documentation(in)=
# begin
#
# out0.antitheftcode::depends_on(
#         in.messageid,
#         in.assetid,
#         in.coverageentcd,
#         in.vehiclesecuritysystemfeaturetypeentcd,
#         in.vehicle_id,
#         in.options.optiontypeentcd,
#         in.options.selectedoptionvalueentcd,
#         in.discount.discountentcd,
#         in.stateproventcd,
#         in.subcoverage.subcoverageentcd,
#         in.peroccurrencedeductibleamt,
#         in.agreement_id,
#         in.perpersonlimitamt
#         );/*@ Rules: [ "Compute antitheftcode" ] @*/
#
# out0.sublinecode::depends_on(
#         in.cededtoreinsurancefacilityind,
#         in.coverageentcd,
#         in.options.optiontypeentcd,
#         in.options.selectedoptionvalueentcd,
#         in.driverexclusionendorsementind,
#         in.stateproventcd,
#         in.consenttorateind,
#         in.subcoverage.subcoverageentcd,
#         in.vehicle_coverageentcd,
#         in.peroccurrencedeductibleamt,
#         in.perpersonlimitamt
#         );/*@ Rules: [ "Compute sublinecode" ] @*/
#
# out0.policyeffectiveyear::depends_on(
#         in.contracttermeffdttimestr
#         );
#
# out0.deductibleamount::depends_on(
#         in.coverageentcd,
#         in.options.optiontypeentcd,
#         in.options.selectedoptionvalueentcd,
#         in.stateproventcd,
#         in.peroccurrencedeductiblepct,
#         in.subcoverage.subcoverageentcd,
#         in.peroccurrencedeductibleamt,
#         in.perpersonlimitamt
#         );/*@ Rules: [ "Compute deductibleamount" ] @*/
#
# out0.defensivedrivercode::depends_on(
#         in.numberofdefensivediscount,
#         in.stateproventcd,
#         lookup("Dynamic Config Profile",'keystr','keystr','keystr').DCP_ATTRIBUTE_TXT
#         );/*@ Rules: [ "Compute defensivedrivercode" ] @*/
#
# out0.companynumber::depends_on(
#         in.accountingcompanyentcd
#         );/*@ Rules: [ "Compute companynumber" ] @*/
#
# out0.deductibleindicatorcode::depends_on(
#         in.coverageentcd,
#         in.options.optiontypeentcd,
#         in.options.selectedoptionvalueentcd,
#         in.stateproventcd,
#         in.peroccurrencedeductiblepct,
#         in.subcoverage.subcoverageentcd,
#         in.peroccurrencedeductibleamt,
#         in.perpersonlimitamt
#         );/*@ Rules: [ "Compute deductibleindicatorcode" ] @*/
#
# out0.manufacturersmodelyear::depends_on(
#         in.coverageentcd,
#         in.options.optiontypeentcd,
#         in.options.selectedoptionvalueentcd,
#         in.stateproventcd,
#         in.subcoverage.subcoverageentcd,
#         in.peroccurrencedeductibleamt,
#         in.accountingyear,
#         in.vehicleyearmakemodel_modelyear,
#         in.perpersonlimitamt
#         );/*@ Rules: [ "Compute manufacturersmodelyear" ] @*/
#
# out0.policyupperlimit::depends_on(
#         in.peroccurrencelimitamt,
#         in.perpersonlimitamt,
#         in.stateproventcd,
#         in.coverageentcd
#         );/*@ Rules: [ "Compute policyupperlimit" ] @*/
#
# out0.zipcode::depends_on(
#         in.postalcode
#         );
#
# out0.coveragecode::depends_on(
#         in.coverageentcd,
#         in.options.selectedoptionvalueentcd,
#         in.options.optiontypeentcd,
#         in.stateproventcd,
#         in.subcoverage.subcoverageentcd,
#         in.peroccurrencedeductibleamt,
#         in.perpersonlimitamt
#         );/*@ Rules: [ "Compute newcoveragecode" ] @*/
#
# out0.annualstatementlobcd::depends_on(
#         in.coverageentcd,
#         in.options.optiontypeentcd,
#         in.options.selectedoptionvalueentcd,
#         in.stateproventcd,
#         in.subcoverage.subcoverageentcd,
#         in.peroccurrencedeductibleamt,
#         in.perpersonlimitamt
#         );/*@ Rules: [ "Compute annualstatementlobcd" ] @*/
#
# out0.policyterm::depends_on(
#         in.transactionefftermdttimestr,
#         in.policystatusentcd,
#         in.contracttermlengthcnt,
#         in.contracttermexpdttimestr,
#         in.transactioneffdttimestr,
#         in.transactiontypeentcd
#         );
#
# out0.daytimerunninglampcode::depends_on(
#         in.discount.discountentcd,
#         in.stateproventcd
#         );/*@ Rules: [ "Compute daytimerunninglampcode" ] @*/
#
# out0.writtenexposure::depends_on(
#         in.transactionefftermdttimestr,
#         in.contracttermeffdttimestr,
#         in.changetypeentcd,
#         in.coverageentcd,
#         in.writtenexposure,
#         in.contracttermexpdttimestr,
#         in.transactioneffdttimestr,
#         in.transactiontypeentcd,
#         in.effdttimestr,
#         in.netchangeamt,
#         in.premiumtypeentcd
#         );/*@ Rules: [ "Compute writtenexposure" ] @*/
#
# out0.statecode::depends_on(
#         in.stateproventcd,
#         lookup("ISO State Code",'keystr').policy_iso_state_code
#         );
#
# out0.ageoldestdriver::depends_on(
#         in.contracttermeffdttimestr,
#         in.birthdtstr2
#         );
#
# out0.stateexceptioncode::depends_on(
#         in.numberofvehiclesunderpolicy,
#         in.genderentcd2,
#         in.participantid3,
#         in.contracttermeffdttimestr,
#         in.birthdtstr2,
#         in.coverageentcd,
#         in.peroccurrencelimitamt,
#         in.options.optiontypeentcd,
#         in.options.selectedoptionvalueentcd,
#         in.vehicleuseentcd,
#         in.vehicletypeentcd,
#         in.discount.discountentcd,
#         in.maritalstatusentcd3,
#         in.participantid1,
#         in.birthdtstr1,
#         in.genderentcd1,
#         in.stateproventcd,
#         in.birthdtstr3,
#         in.maritalstatusentcd2,
#         in.subcoverage.subcoverageentcd,
#         in.discount,
#         in.vehicle_coverageentcd,
#         in.peroccurrencedeductibleamt,
#         in.maritalstatusentcd1,
#         in.participantid2,
#         in.genderentcd3,
#         in.perpersonlimitamt
#         );/*@ Rules: [ "Compute stateexceptioncode" ] @*/
#
# out0.territorycode::depends_on(
#         in.postalcode,
#         in.stateproventcd,
#         lookup("Territory Code",'keystr').territory_code
#         );/*@ Rules: [ "Compute territorycode" ] @*/
#
# out0.agemaledriver::depends_on(
#         in.contracttermeffdttimestr,
#         in.birthdtstr1
#         );
#
# out0.classificationcode::depends_on(
#         in.numberofvehiclesunderpolicy,
#         in.genderentcd2,
#         in.participantid3,
#         in.contracttermeffdttimestr,
#         in.birthdtstr2,
#         in.coverageentcd,
#         in.vehicleuseentcd,
#         in.vehicletypeentcd,
#         in.discount.discountentcd,
#         in.maritalstatusentcd3,
#         in.participantid1,
#         in.birthdtstr1,
# ...
#     stateexceptioncode='07';
#   end
#   else if(first_defined(fail_if_error((! classificationcode  member  [vector "9997","9995"]) && (bzt_71 ==686) && (bzt_72 ==200000)),0))begin
#     stateexceptioncode='04';
#   end
#   else if(first_defined(fail_if_error((! classificationcode  member  [vector "9997","9995"]) && (bzt_71 ==686) && (bzt_72 ==277500)),0))begin
#     stateexceptioncode='05';
#   end
#   else if(first_defined(fail_if_error((! classificationcode  member  [vector "9997","9995"]) && (bzt_71 ==686) && (! bzt_72  member  [vector 12500,17500,50000,100000,177500,200000,277500])),0))begin
#     stateexceptioncode='09';
#   end
#   else if(first_defined(fail_if_error((classificationcode  member  [vector "9997","9995"]) && (bzt_71  member  [vector 680,681,682,686]) && (bzt_72 ==100000)),0))begin
#     stateexceptioncode='01';
#   end
#   else if(first_defined(fail_if_error((classificationcode  member  [vector "9997","9995"]) && (bzt_71  member  [vector 680,681,682,686]) && (bzt_72 ==300000)),0))begin
#     stateexceptioncode='02';
#   end
#   else if(first_defined(fail_if_error((classificationcode  member  [vector "9997","9995"]) && (bzt_71  member  [vector 680,681,682,686]) && (bzt_72 ==500000)),0))begin
#     stateexceptioncode='03';
#   end
#   else if(first_defined(fail_if_error((classificationcode  member  [vector "9997","9995"]) && (bzt_71  member  [vector 680,681,682,686]) && (bzt_72 ==1000000)),0))begin
#     stateexceptioncode='04';
#   end
#   else if(first_defined(fail_if_error((classificationcode  member  [vector "9997","9995"]) && (bzt_71  member  [vector 680,681,682,686]) && (! bzt_72  member  [vector 100000,300000,500000,1000000])),0))begin
#     stateexceptioncode='09';
#   end
# end
# case 'NJ':
# begin
#   if(first_defined(fail_if_error((annualstatementlobcd  member  [vector '192','211'])),0))begin
#     stateexceptioncode='00';
#   end
#   else if(first_defined(fail_if_error((annualstatementlobcd =='191') && (bzt_74 < 2) && (pipmedicalcoverageind ==0)),0))begin
#     stateexceptioncode='00';
#   end
#   else if(first_defined(fail_if_error((annualstatementlobcd =='191') && (bzt_74 >= 2) && (pipmedicalcoverageind ==0)),0))begin
#     stateexceptioncode='03';
#   end
#   else if(first_defined(fail_if_error((annualstatementlobcd =='191') && (bzt_74 < 2) && (pipmedicalcoverageind ==1)),0))begin
#     stateexceptioncode='01';
#   end
#   else if(first_defined(fail_if_error((annualstatementlobcd =='191') && (bzt_74 >= 2) && (pipmedicalcoverageind ==1)),0))begin
#     stateexceptioncode='02';
#   end
# end
# end
#
#   out0.statisticalstateproventcd::statisticalstateproventcd;
#   out0.companynumber::companynumber;
#   out0.lineofbusinesscode::lineofbusinesscode;
#   out0.statecode::statecode;
#   out0.callyear::callyear;
#   out0.accountingquarter::accountingquarter;
#   out0.experienceperiodyear::experienceperiodyear;
#   out0.experienceperiodmonth::experienceperiodmonth;
#   out0.experienceperiodday::experienceperiodday;
#   out0.coveragecode::coveragecode;
#   out0.classificationcode::classificationcode;
#   out0.typeoflosscode::typeoflosscode;
#   out0.territorycode::territorycode;
#   out0.zipcode::zipcode;
#   out0.policyeffectiveyear::policyeffectiveyear;
#   out0.stateexceptioncode::stateexceptioncode;
#   out0.annualstatementlobcd::annualstatementlobcd;
#   out0.deductibleindicatorcode::deductibleindicatorcode;
#   out0.deductibleamount::deductibleamount;
#   out0.sublinecode::sublinecode;
#   out0.manufacturersmodelyear::manufacturersmodelyear;
#   out0.agegroupcode::agegroupcode;
#   out0.antitheftcode::antitheftcode;
#   out0.daytimerunninglampcode::daytimerunninglampcode;
#   out0.defensivedrivercode::defensivedrivercode;
#   out0.exceptionbcode::exceptionbcode;
#   out0.policyterm::policyterm;
#   out0.penaltypoints::penaltypoints;
#   out0.policylowerlimit::policylowerlimit;
#   out0.policyupperlimit::policyupperlimit;
#   out0.symbolcode::symbolcode;
#   out0.policyidcode::policyidcode;
#   out0.passiverestraintcode::passiverestraintcode;
#   out0.ratingzonecode::ratingzonecode;
#   out0.terminalzonecode::terminalzonecode;
#   out0.forgivenesscode::forgivenesscode;
#   out0.claimidentifier::claimidentifier;
#   out0.claimantidentifier::claimantidentifier;
#   out0.writtenexposure::writtenexposure;
#   out0.writtenpremium::writtenpremium;
#   out0.paidlosses::paidlosses;
#   out0.paidclaims::paidclaims;
#   out0.paidallocatedlossadjustmentexpense::paidallocatedlossadjustmentexpense;
#   out0.outstandinglosses::outstandinglosses;
#   out0.outstandingclaims::outstandingclaims;
#   out0.outstandingallocatedlossadjexp::outstandingallocatedlossadjexp;
#   out0.limitcode::limitcode;
#   out0.filingtype::filingtype;
#   out0.filingruntimestamp::filingruntimestamp;
#   out0.filingrulesversion::filingrulesversion;
#   out0.agemaledriver::agemaledriver;
#   out0.ageyoungestdriver::ageyoungestdriver;
#   out0.ageoldestdriver::ageoldestdriver;
#   out0.*::in0.*;
# end;
#
# === Example ===
# Example case study is:
#
# ### START EXAMPLE CASE STUDY
#
# **Converting the ASC_VIP_Premium Ab Initio Workflow to PySpark**
#
# Below is a complete walkthrough showing how to translate the Ab Initio *ASC_VIP_Premium* workflow (defined in a `.xfr` transform) into an equivalent, modular PySpark pipeline.
# The pipeline reads source data, applies every business rule, and writes an output DataFrame that matches the required layout.
#
# ---
#
# ## 1 Input Data Schema and Loading
#
# We start by defining the schema described in `simple_input_layout.txt`.
# All original fields are `hive_string_t`, so we map them to `StringType` in Spark:
#
# ```python
# from pyspark.sql.types import StructType, StructField, StringType
#
# input_schema = StructType([
#     StructField("messageid",             StringType(), True),
#     StructField("agreementid",           StringType(), True),
#     StructField("systementcd",           StringType(), True),
#     StructField("sourcesystementcd",     StringType(), True),
#     StructField("transactionuserid",     StringType(), True),
#     StructField("transactioneffdttime",  StringType(), True),
#     StructField("transactiontypeentcd",  StringType(), True),
#     StructField("transactionprocesseddttimestr", StringType(), True),
#     StructField("policynbr",             StringType(), True),
#     StructField("policyversionnbr",      StringType(), True),
#     StructField("premiumTypeEntCd",      StringType(), True),
#     StructField("contracttermexpdttimestr", StringType(), True),
#     StructField("contracttermlengthcnt", StringType(), True),
#     StructField("contracttermeffdttime", StringType(), True),
#     StructField("downPaymentAmtStr",     StringType(), True),
#     StructField("downPaymentPct",        StringType(), True),
#     StructField("downPaymentPctStr",     StringType(), True),
#     StructField("accountingcompanyentcd",StringType(), True),
#     StructField("stateproventcd",        StringType(), True),
#     StructField("coverageentcd",         StringType(), True),
#     StructField("coverageeffdttimestr",  StringType(), True),
#     StructField("postalcode",            StringType(), True),
#     StructField("fiscalperiod",          StringType(), True),
#     StructField("peroccurrencelimitamtstr", StringType(), True),
#     StructField("totalpremiumamtstr",    StringType(), True),
#     StructField("fipscountyentcd",       StringType(), True),
#     StructField("allstatecountycd",      StringType(), True),
#     StructField("cityname",              StringType(), True),
#     StructField("policystatusentcd",     StringType(), True),
#     StructField("policyterminatedentcd", StringType(), True),
#     StructField("netchangeamt",          StringType(), True),
#     StructField("recordtype",            StringType(), True),
#     StructField("batchid",               StringType(), True),
#     StructField("rawfilename",           StringType(), True),
#     StructField("recordsequenceid",      StringType(), True),
#     StructField("accountingyear",        StringType(), True),
#     StructField("accountingmonth",       StringType(), True)
# ])
#
# df_input = (
#     spark.read.format("csv")
#     .schema(input_schema)
#     .option("header", "false")
#     .load("/path/to/ASC_VIP_Premium_input_data")
# )
# ```
#
# *(In production you may load from Hive or Parquet; keeping everything as strings preserves fidelity with the Ab Initio types.)*
#
# ---
#
# ## 2 Transformation Functions
#
# ### 2.1 Company Number Mapping
#
# ```python
# import pyspark.sql.functions as F
#
# COMPANY_MAP = {
#     10:  "0031",  27:  "1585",  20:  "0025",  21:  "0776",  22:  "0002",
#     60:  "0520",  63:  "0467",  64:  "0067",  65:  "0458",  68:  "1305",
#     70:  "0420",  85:  "0517",  95:  "0522",  330: "1481",  270: "0192",
#     339: "1437",  365: "1534",  382: "1546",  383: "1545",  357: "1562",
#     359: "1564",  360: "1560",  361: "1561",  367: "1563",  387: "2206",
#     386: "2207"
# }
# DEFAULT_COMPANY = "1481"
#
# def add_companynumber(df):
#     return df.withColumn(
#         "companynumber",
#         F.coalesce(
#             F.expr(
#                 "CASE CAST(accountingcompanyentcd AS INT) " +
#                 " ".join([f"WHEN {k} THEN '{v}'" for k, v in COMPANY_MAP.items()]) +
#                 " END"
#             ),
#             F.lit(DEFAULT_COMPANY)
#         )
#     )
# ```
#
# ### 2.2 Policy Term Calculation
#
# ```python
# from pyspark.sql.functions import year, month, to_timestamp, lit, lpad
#
# def add_policyterm(df):
#     df = (
#         df.withColumn("trans_eff_dt", to_timestamp("transactioneffdttime"))
#           .withColumn("term_exp_dt",  to_timestamp("contracttermexpdttimestr"))
#           .withColumn("term_eff_dt",  to_timestamp("contracttermeffdttime"))
#           .withColumn(
#               "month_diff",
#               (year("term_exp_dt") - year("trans_eff_dt")) * 12 +
#               (month("term_exp_dt") - month("trans_eff_dt"))
#           )
#     )
#
#     cond_newbiz          = F.col("transactiontypeentcd") == lit("0001")
#     cond_endorse_nonzero = F.col("transactiontypeentcd").isin("0002", "0010") & (F.col("month_diff") != 0)
#     cond_endorse_zero    = F.col("transactiontypeentcd").isin("0002", "0010") & (F.col("month_diff") == 0)
#     cond_cancel          = F.col("transactiontypeentcd").isin("0004", "0012")
#     cond_cancel_sameDay  = cond_cancel & (F.to_date("trans_eff_dt") == F.to_date("term_eff_dt"))
#     cond_cancel_ge12     = cond_cancel & (F.col("month_diff") >= 12)
#     cond_cancel_le1      = cond_cancel & (F.col("month_diff") <= 1)
#
#     df = df.withColumn(
#         "policyterm",
#         F.when(cond_newbiz, lpad("contracttermlengthcnt", 2, "0"))
#          .when(cond_endorse_nonzero, lpad(F.col("month_diff").cast("string"), 2, "0"))
#          .when(cond_endorse_zero,    lit("01"))
#          .when(cond_cancel_sameDay,  lpad("contracttermlengthcnt", 2, "0"))
#          .when(cond_cancel_ge12,     lit("11"))
#          .when(cond_cancel_le1,      lit("01"))
#          .when(cond_cancel,          lpad(F.col("month_diff").cast("string"), 2, "0"))
#          .otherwise(lpad("contracttermlengthcnt", 2, "0"))
#     )
#
#     return df.drop("trans_eff_dt", "term_exp_dt", "term_eff_dt", "month_diff")
# ```
#
# ### 2.3 Policy Effective Year
#
# ```python
# def add_policyeffectiveyear(df):
#     df = (
#         df.withColumn("trans_eff_date",      to_timestamp("transactioneffdttime"))
#           .withColumn("policy_term_eff_date", to_timestamp("contracttermeffdttime"))
#     )
#
#     cond_endorse    = F.col("transactiontypeentcd") == lit("0002")
#     cond_cancel_mid = (
#         F.col("transactiontypeentcd").isin("0004", "0012") &
#         (F.to_date("trans_eff_date") != F.to_date("policy_term_eff_date"))
#     )
#
#     df = df.withColumn(
#         "policyeffectiveyear",
#         F.when(cond_endorse | cond_cancel_mid, F.date_format("trans_eff_date", "yyyy"))
#          .otherwise(F.date_format("policy_term_eff_date", "yyyy"))
#     )
#
#     return df.drop("trans_eff_date", "policy_term_eff_date")
# ```
#
# ### 2.4 Classification Code Mapping
#
# ```python
# def add_classificationcode(df):
#     cov   = F.col("coverageentcd").cast("int")
#     state = F.col("stateproventcd")
#
#     df = df.withColumn(
#         "classificationcode",
#         F.when((state != "NY") & (cov == 317), "722000")
#          .when((state != "NY") & (cov == 318), "709700")
#          .when((state != "NY") & (cov == 319), "721000")
#          .when((state != "NY") & (cov == 320), "751300")
#          .when((state != "NY") & (cov == 321), "751500")
#          .when((state != "NY") & (cov == 322), "799900")
#          .when((state != "NY") & (cov == 323), "714400")
#          .when((state != "NY") & (cov == 324), "714200")
#          .when((state != "NY") & (cov == 325), "717700")
#          .when((state == "NY") & (cov == 317), "703200")
#          .when((state == "NY") & (cov == 319), "705100")
#          .otherwise("")
#     )
#     return df
# ```
#
# ### 2.5 Miscellaneous Constant / Simple Fields
#
# ```python
# from datetime import datetime
#
# def add_misc_fields(df, filing_version="1.0"):
#     run_ts = datetime.now().strftime("%Y-%m-%d%H:%M:%S")
#
#     return (
#         df
#         .withColumn("lineofbusinesscode",  F.lit("06"))
#         .withColumn("statecode",           F.col("stateproventcd"))
#         .withColumn(
#             "callyear",
#             F.when(F.col("accountingyear").cast("int").isNotNull(),
#                    (F.col("accountingyear").cast("int") + 1).cast("string"))
#              .otherwise(F.lit(""))
#         )
#         .withColumn("experienceperiodyear", F.lit("0000"))
#         .withColumn("experienceperiodmonth",F.lit("00"))
#         .withColumn("experienceperiodday",  F.lit("00"))
#         .withColumn("typeoflosscode",       F.lit("00"))
#         .withColumn("annualstatementlobcd", F.lit("091"))
#         .withColumn("policyidentification", F.lit("10"))
#         .withColumn("claimantidentifier",   F.lit("000"))
#         .withColumn("claimidentifier",      F.lit("0"*15))
#         .withColumn("writtenpremium",
#                     F.when(F.length("netchangeamt") > 0, F.col("netchangeamt"))
#                      .otherwise(F.lit("0")))
#         .withColumn("paidlosses",           F.lit("0"*12))
#         .withColumn("paidclaims",           F.lit("0"*12))
#         .withColumn("outstandinglosses",    F.lit("0"*12))
#         .withColumn("outstandingclaims",    F.lit("0"*12))
#         .withColumn("filingtype",           F.lit("PREMIUM"))
#         .withColumn("filingruntimestamp",   F.lit(run_ts))
#         .withColumn("filingsversion",       F.lit(filing_version))
#     )
# ```
#
# ---
#
# ## 3 End-to-End Pipeline Assembly
#
# ```python
# df_transformed = df_input
# df_transformed = add_companynumber(df_transformed)
# df_transformed = add_policyterm(df_transformed)
# df_transformed = add_policyeffectiveyear(df_transformed)
# df_transformed = add_classificationcode(df_transformed)
# df_transformed = add_misc_fields(df_transformed, filing_version="1.0")
# ```
#
# ### Select Final Output Columns
#
# ```python
# df_output = df_transformed.select(
#     "messageid", "agreementid", "companynumber", "lineofbusinesscode", "statecode",
#     "callyear", "experienceperiodyear", "experienceperiodmonth", "experienceperiodday",
#     "classificationcode", "typeoflosscode", "policyeffectiveyear",
#     "annualstatementlobcd", "policyidentification", "policyterm",
#     "claimantidentifier", "claimidentifier", "writtenpremium",
#     "paidlosses", "paidclaims", "outstandinglosses", "outstandingclaims",
#     "policynbr", "recordsequenceid", "policyversionnbr", "coverageentcd",
#     "transactiontypeentcd", "recordtype", "filingtype", "filingruntimestamp",
#     "filingsversion", "accountingyear", "accountingmonth"
# )
# ```
#
# ---
#
# ## 4 Writing the Output
#
# ```python
# # As Parquet
# df_output.write.mode("overwrite").parquet("/path/to/output/ASC_VIP_Premium_transformed.parquet")
#
# # Or as a Hive table
# df_output.write.mode("overwrite").saveAsTable("prod.asc_vip_premium_output")
# ```
#
# The resulting Parquet files (or Hive table) exactly match the required output schema while implementing every business rule from the original Ab Initio workflow in PySpark.
#
# ### END EXAMPLE CASE STUDY
#
#
# ================================================================
# Produce only the PySpark script:
# ```python
# # (model inserts the complete Databricks-ready PySpark code with inline comments)

# %% [markdown]
# ## Develop the case study
#
# ## Generate and Review Code
#
# Generate PySpark code from the input XFR file and perform a detailed code review to ensure:
# - Schema alignment
# - Performance optimization
# - Best practices compliance
# - Security and governance

# %%
# 1️⃣  Call the model
output_case_study = o3minicall(scenario, "high")
markdown_text = output_case_study.choices[0].message.content

# 2️⃣  Destination: remove the "file:" prefix and (optionally) create the folder first
folder_path = "Files/code-conversion-data/solution"   # absolute OneLake path
file_name   = "solution_with_details.py"
dest_path   = f"{folder_path}/{file_name}"

from notebookutils import mssparkutils   # Fabric import

# Make sure the folder exists (creates it if missing)
mssparkutils.fs.mkdirs(folder_path)

# 3️⃣  Write the markdown file
mssparkutils.fs.put(dest_path, markdown_text, overwrite=True)
print(f"✅ Saved markdown to {dest_path}")
# Out:
# StatementMeta(, d9203f8a-a3fe-461c-a791-1d49e6717b79, 18, Finished, Cancelled, Cancelled)

# %%
from notebookutils import mssparkutils

path = "Files/code-conversion-data/solution/solution_with_details.py"
print(mssparkutils.fs.head(path, 1024))   # first 1 KB
# Out:
# StatementMeta(, 86022f1e-6446-40c9-84dc-198bd42ff73c, 63, Finished, Available, Finished)
# ```python
# from pyspark.sql import SparkSession
# from pyspark.sql.functions import (
#     col, lit, when, expr, size, filter, concat, substring, to_date,
#     to_timestamp, date_format, year, month, datediff, abs as sql_abs,
#     round as sql_round, regexp_replace
# )
# from pyspark.sql.types import (
#     StructType, StructField, StringType
# )
#
# # Constants block: mapping and file parameters
# COMPANY_MAP = {
#     10: "0031", 27: "1585", 20: "0025", 21: "0776", 22: "0002",
#     60: "0520", 63: "0467", 64: "0067", 65: "0458", 68: "1305",
#     70: "0420", 85: "0517", 95: "0522", 330: "1481", 270: "0192",
#     339: "1437", 365: "1534", 382: "1546", 383: "1545", 357: "1562",
#     359: "1564", 360: "1560", 361: "1561", 367: "1563", 387: "2206",
#     386: "2207"
# }
# DEFAULT_COMPANY = "1481"
# FILING_YEAR_MONTH = dbutils.widgets.get("FILING_YEAR_MONTH")  # e.g. "202301"
# FILING_VERSION     = dbutils.widgets.get("FILING_VERSION")    # e.g. "4.1.5.7"
#
# def add_company_number(df):
#     # Map accountingcompanyentcd to companynumber via COMPANY_M

# %%
code_review_prompt=f"""
You are a principal Spark architect and code-review specialist.

=============================  TASK 1 - DETAILED REVIEW  =============================
**Cross-check the code against the supplied Input Layout and Output Layout.**  
For every issue you find, cite the offending line(s) or snippet.

A. Schema Mismatches  
  - Columns or types that do not exist in the input layout but are referenced.  
  - Missing required output columns or wrong data types for them.

B. Unused or Redundant Elements  
  - Columns, UDFs, caches, or joins that are created but never used downstream.

C. Performance Risks  
  - Wide shuffles, high-cardinality joins without broadcast/salt, `.collect()` on large DFs, `.repartition(1)`, etc.

D. Anti-Patterns & Style  
  - Hard-coded paths, secrets, magic numbers, long monolithic functions, non-PEP-8 names, replaceable UDFs.

E. Security / Governance  
  - Exposure of PII, unmasked secrets, non-encrypted S3/ADLS paths.

Return the review in **markdown** with four sections:
- **Critical Issues**   (must fix for correctness)  
- **Performance Risks**  
- **Style / Maintainability**  
- **Quick Wins**

=============================  TASK 2 - AUTO-REFACTOR  =============================
Produce a **single, complete Python code block** that resolves every Critical Issue:

* Align all source reads and writes with the provided layouts.  
* Drop unused columns early; broadcast or cache judiciously.  
* Replace UDFs with native Spark SQL functions when feasible.  
* Parameterize paths/secrets; follow PEP-8 (`snake_case`, <= 79-char lines).  
* Annotate each major step with a brief comment (what & why).  
* Guarantee the final DataFrame exactly matches the **Output Layout**.

Output format:
```markdown
### Review
- ...

### Refactored Code
```python
# full, runnable PySpark script with improvements
# ...

=============================  CONTEXT  SECTION  =============================
## Input Layout (complete file)
<input_layout>
{input_layout_content}
</input_layout>

## Output Layout (complete file)
<output_layout>
{output_layout_content}
</output_layout>

## Additional Context (optional)
<constraints>

</constraints>

## PySpark Code to Review
<code>
{output_case_study.choices[0].message.content}
</code>
----------------------------------------------------------------
"""
# Out:
# StatementMeta(, 86022f1e-6446-40c9-84dc-198bd42ff73c, 64, Finished, Available, Finished)

# %%
code_review_python=f"""
You are a principal Spark architect and code-review specialist.

Your mission:

1. **Analyse** the PySpark code against the supplied *Input Layout* and *Output Layout*.  
   - Find schema mismatches, unused columns, performance risks, anti-patterns, and security issues.  
   - Resolve every Critical Issue in the refactor.

2. **Deliver exactly one thing**:  
   **→ A single, complete PySpark code block** that incorporates all fixes and contains concise inline comments explaining *what was changed and why*.  
   - No prose, no review section, no headings—just the final script inside triple back-ticks.  
   - Conform to PEP-8 (`snake_case`, <= 79-char lines).  
   - Align reads/writes with the provided layouts.  
   - Drop unused columns early; use broadcast/caching judiciously.  
   - Replace UDFs with native Spark SQL functions where possible.  
   - Parameterise paths/secrets.  
   - Ensure the resulting DataFrame exactly matches the **Output Layout**.

Return format **must be only**:

```python
# refactored, runnable PySpark script with inline comments
# ...

=============================  CONTEXT  SECTION  =============================
## Input Layout (complete file)
<input_layout>
{input_layout_content}
</input_layout>

## Output Layout (complete file)
<output_layout>
{output_layout_content}
</output_layout>

## Additional Context (optional)
<constraints>
Running on Databricks Runtime 13.x, auto-scaling 2-8 nodes
</constraints>

## PySpark Code to Review
<code>
{output_case_study.choices[0].message.content}
</code>
----------------------------------------------------------------
"""
# Out:
# StatementMeta(, 86022f1e-6446-40c9-84dc-198bd42ff73c, 65, Finished, Available, Finished)

# %%
# code_review=o3minicall(code_review_prompt,"high")
# print(code_review.choices[0].message.content)
# Out:
# ### Review
# #### Critical Issues
# 1. **Syntax error – code will not run**
#    ```python
#    F.create_map(
#        *[F.lit(str(k)), F.lit(v) for k, v in COMPANY_MAP.items()]
#    )
#    ```
#    ‑ Python does not allow two expressions inside one list-comprehension element; this
#    raises `SyntaxError` before the job starts.
#
# 2. **Input schema hard-coded as “all strings”**
#    ```python
#    spark.read.schema(input_schema).parquet(input_path)
#    ```
#    The real parquet contains arrays & structs (e.g. `participants`, `discount`).
#    Forcing them into `StringType()` causes a run-time “Cannot up-cast” error.
#
# 3. **Mandatory output columns left NULL instead of being derived**
#    * `statecode`, `statisticalstateproventcd`, `zipcode` are present in
#      the source but never populated.
#    * Business-critical columns like `classificationcode`, `limitcode` etc.
#      are silently nulled—violates downstream contract.
#
# 4. **Python UDFs used for simple logic**
#    `lookup_territory` and `years_between` force the plan into
#    the slow, non-vectorised UDF path and block Catalyst optimisation.
#
# 5. **Unnecessary cache**
#    ```python
#    df = df.cache()
#    ```
#    The cached DataFrame is never referenced again, wasting cluster memory.
#
# #### Performance Risks
# * Wide `create_map` literal that will be shipped with every task instead of
#   doing a one-time broadcast join.
# * `.to_date()` without format forces expensive pattern tries for every row.
# * Overwrite write-mode on large paths can trigger name-node storms.
# * Python UDFs (see #4) prevent Tungsten code-gen.
#
# #### Style / Maintainability
# * MixedCase function names (`add_company_number`) vs snake_case in others.
# * Hard-coded dictionary data instead of loading from Delta/Hive look-ups.
# * Magic strings (`"Premium"`, `"v1"`, `"55"`, …) scattered in code.
# * One monolithic `main()` – no unit-testable sub-pipelines.
#
# #### Quick Wins
# * Replace UDFs with `rlike`, `substr`, arithmetic.
# * Drop `.cache()`.
# * Fill `zipcode` via `postalcode`; add `statecode`, `statisticalstateproventcd`
#   by simple alias.
# * Build the company map as a two-column DataFrame and broadcast-join.
# * Read source without an explicit schema, then `.selectExpr()` the needed
#   string columns.
#
# ---
#
# ### Refactored Code
# ```python
# # ====================  Imports & Constants  ==================================
# from pyspark.sql import SparkSession
# import pyspark.sql.functions as F
# from pyspark.sql.types import StringType, StructType, StructField
# from datetime import datetime
# from typing import List
#
# #  ---- mapping tables (would normally live in Delta/Hive) --------------------
# COMPANY_MAP = {
#     10: "0031", 27: "1585", 20: "0025", 21: "0776", 22: "0002", 60: "0520",
#     63: "0467", 64: "0067", 65: "0458", 68: "1305", 70: "0420", 85: "0517",
#     95: "0522", 330: "1481", 270: "0192", 339: "1437", 365: "1534",
#     382: "1546", 383: "1545", 357: "1562", 359: "1564", 360: "1560",
#     361: "1561", 367: "1563", 387: "2206", 386: "2207"
# }
# DEFAULT_COMPANY = "1481"
#
# TERRITORY_LOOKUP = {
#     "FL": [(".*", "01")],
#     "CT": [(".*", "02")],
#     "NJ": [(".*", "03")]
# }
#
# LOB_192 = {...}  # truncated for brevity – identical to original
# LOB_191 = {...}
#
# # ================  Utility: DML → StructType (output only)  ==================
# def parse_hive_layout(layout_text: str) -> StructType:
#     """Return a StructType containing every hive_string_t field."""
#     fields: List[StructField] = []
#     for ln in layout_text.splitlines():
#         if "hive_string_t" in ln:
#             name = ln.split()[1]
#             fields.append(StructField(name.lower(), StringType(), True))
#     return StructType(fields)
#
# # ==================  Rule Functions  =========================================
# def add_company_number(df):
#     """
#     accountingcompanyentcd -> 4-char companynumber via broadcast table.
#     """
#     mapping_df = (
#         spark.createDataFrame(
#             [(str(k), v) for k, v in COMPANY_MAP.items()],
#             ["accountingcompanyentcd", "companynumber"]
#         )
#     )
#     df = df.withColumn(
#         "accountingcompanyentcd", F.col("accountingcompanyentcd").cast("string")
#     )
#     return (
#         df.join(
#             F.broadcast(mapping_df),
#             on="accountingcompanyentcd",
#             how="left"
#         )
#         .withColumn(
#             "companynumber",
#             F.coalesce("companynumber", F.lit(DEFAULT_COMPANY))
#         )
#     )
#
# def add_territory_code(df):
#     """
#     Regex-based state + postalcode → territorycode without Python UDF.
#     """
#     expr = F.lit("00")
#     for st, rules in TERRITORY_LOOKUP.items():
#         for pattern, code in rules:
#             expr = F.when(
#                 (F.col("stateproventcd") == st)
#                 & F.col("postalcode").rlike(pattern),
#                 F.lit(code)
#             ).otherwise(expr)
#     return df.withColumn("territorycode", expr)
#
# def add_calendar_fields(df):
#     """callyear and accountingquarter from accountingyear/month."""
#     df = df.withColumn(
#         "callyear", (F.col("accountingyear").cast("int") + 1).cast("string")
#     )
#     month_int = F.col("accountingmonth").cast("int")
#     df = df.withColumn(
#         "accountingquarter",
#         F.when(month_int.between(1, 3),  "1")
#          .when(month_int.between(4, 6),  "2")
#          .when(month_int.between(7, 9),  "3")
#          .when(month_int.isNull(),       None)
#          .otherwise("4")
#     )
#     return df
#
# def add_policy_effective_year(df):
#     return df.withColumn(
#         "policyeffectiveyear", F.col("contracttermeffdttimestr").substr(1, 4)
#     )
#
# def add_age_fields(df):
#     """Age = eff-year minus birth-year (string math → avoid UDF)."""
#     eff_year = F.col("contracttermeffdttimestr").substr(1, 4).cast("int")
#     def age(col_name):
#         return (eff_year - F.col(col_name).substr(1, 4).cast("int")).cast("string")
#     return (
#         df.withColumn("agemaledriver",      age("birthdtstr1"))
#           .withColumn("ageyoungestdriver",  age("birthdtstr3"))
#           .withColumn("ageoldestdriver",    age("birthdtstr2"))
#     )
#
# def add_policy_term(df):
#     """
#     Months between eff and exp.  If exp < eff or nulls → 00.
#     """
#     df = df.withColumn(
#         "policyterm",
#         F.lpad(
#             F.when(
#                 (F.to_date("contracttermeffdttimestr") < F.to_date("contracttermexpdttimestr")),
#                 F.months_between(
#                     F.to_date("contracttermexpdttimestr"),
#                     F.to_date("contracttermeffdttimestr")
#                 ).cast("int")
#             ).otherwise(0).cast("string"),
#             2, "0"
#         )
#     )
#     return df
#
# def add_writtenpremium_and_deductibles(df):
#     df = df.withColumn(
#         "writtenpremium", F.coalesce("netchangeamt", F.lit("0"))
#     )
#
#     num_amt = F.col("peroccurrencedeductibleamt").cast("double")
#     df = df.withColumn(
#         "deductibleamount",
#         F.when(num_amt > 0, F.lpad(F.col("peroccurrencedeductibleamt"), 7, "0"))
#          .otherwise(F.lit(" "))
#     ).withColumn(
#         "deductibleindicatorcode",
#         F.when(num_amt > 0, F.lit("D")).otherwise(F.lit(" "))
#     )
#     return df
#
# def add_coverage_fields(df):
#     cov_int = F.col("coverageentcd").cast("int")
#     state   = F.col("stateproventcd")
#     df = df.withColumn(
#         "coveragecode",
#         F.when((state == "FL") & cov_int.isin(73, 182, 66), "203")
#          .when(cov_int == 1,  "001")
#          .when(cov_int == 16, "003")
#          .when(cov_int == 73, "201")
#          .otherwise("999")
#     )
#     df = df.withColumn(
#         "annualstatementlobcd",
#         F.when(F.col("coveragecode").isin(list(LOB_192)), "192")
#          .when(F.col("coveragecode").isin(list(LOB_191)), "191")
#          .otherwise("211")
#     )
#     return df
#
# def add_misc_defaults(df):
#     """Populate constants & easy aliases."""
#     now_ts = datetime.utcnow().strftime("%Y-%m-%d %H:%M:%S")
#
#     return (
#         df
#         # simple copies
#         .withColumn("statecode",               F.col("stateproventcd"))
#         .withColumn("statisticalstateproventcd", F.col("stateproventcd"))
#         .withColumn("zipcode",                 F.col("postalcode"))
#         # constants
#         .withColumn("lineofbusinesscode",      F.lit("55"))
#         .withColumn("typeoflosscode",          F.lit("00"))
#         .withColumn("experienceperiodyear",    F.lit("0000"))
#         .withColumn("experienceperiodmonth",   F.lit("00"))
#         .withColumn("experienceperiodday",     F.lit("00"))
#         .withColumn("symbolcode",              F.lit("00"))
#         .withColumn("policyidcode",            F.lit("10"))
#         .withColumn("ratingzonecode",          F.lit("0"))
#         .withColumn("terminalzonecode",        F.lit("00"))
#         .withColumn("claimidentifier",         F.lit("000000000000000"))
#         .withColumn("claimantidentifier",      F.lit("000"))
#         .withColumn("paidlosses",              F.lit("000000000000"))
#         .withColumn("paidclaims",              F.lit("000000000000"))
#         .withColumn("paidallocatedlossadjustmentexpense",
#                     F.lit("000000000000"))
#         .withColumn("outstandinglosses",       F.lit("000000000000"))
#         .withColumn("outstandingclaims",       F.lit("000000000000"))
#         .withColumn("outstandingallocatedlossadjexp",
#                     F.lit("000000000000"))
#         .withColumn("filingtype",              F.lit("Premium"))
#         .withColumn("filingruntimestamp",      F.lit(now_ts))
#         .withColumn("filingrulesversion",      F.lit("v1"))
#     )
#
# # ==================  Main Pipeline ===========================================
# def main(spark, input_path, output_path, output_layout_text):
#     # 1. Read source (let Spark infer complex schema), cast to strings where
#     #    we care.  Selecting all keeps the job future-proof.
#     df = spark.read.parquet(input_path)
#
#     # 2. Business rules in sequence
#     df = add_company_number(df)
#     df = add_territory_code(df)
#     df = add_calendar_fields(df)
#     df = add_policy_effective_year(df)
#     df = add_age_fields(df)
#     df = add_policy_term(df)
#     df = add_writtenpremium_and_deductibles(df)
#     df = add_coverage_fields(df)
#     df = add_misc_defaults(df)
#
#     # 3. Conform to target schema
#     out_schema = parse_hive_layout(output_layout_text)
#     out_cols   = [f.name for f in out_schema.fields]
#
#     for c in out_cols:
#         if c not in df.columns:
#             df = df.withColumn(c, F.lit(None).cast(StringType()))
#
#     df_final = df.select(*out_cols)
#
#     # 4. Write as partition-friendly parquet
#     (df_final
#      .write
#      .mode("overwrite")          # param-driven in prod
#      .parquet(output_path))
#
# # ==================  Entry-point =============================================
# if __name__ == "__main__":
#     spark = (
#         SparkSession.builder
#         .appName("PersonalAuto_iFiling_Premium")
#         .getOrCreate()
#     )
#
#     INPUT_PATH  = "/mnt/raw/personal_auto_premium"     # param / widget
#     OUTPUT_PATH = "/mnt/curated/personal_auto_premium"
#
#     # In Databricks use widgets or secrets; simplified here
#     output_layout_text = (
#         spark.read.text("/FileStore/layouts/output_layout.dml")
#               .selectExpr("collect_list(value) as txt")
#               .first()["txt"]
#     )
#     output_layout_text = "\n".join(output_layout_text)
#
#     main(spark, INPUT_PATH, OUTPUT_PATH, output_layout_text)
#     spark.stop()
# ```

# %%
# 1️⃣  Call the model
code_review=o3minicall(code_review_prompt,"high")
markdown_text_review = code_review.choices[0].message.content

# 2️⃣  Destination: remove the "file:" prefix and (optionally) create the folder first
folder_path = "Files/code-conversion-data/solution"   # absolute OneLake path
file_name   = "code_review_with_details.md"
dest_path   = f"{folder_path}/{file_name}"

from notebookutils import mssparkutils   # Fabric import

# Make sure the folder exists (creates it if missing)
mssparkutils.fs.mkdirs(folder_path)

# 3️⃣  Write the markdown file
mssparkutils.fs.put(dest_path, markdown_text_review, overwrite=True)
print(f"✅ Saved markdown to {dest_path}")
# Out:
# StatementMeta(, 86022f1e-6446-40c9-84dc-198bd42ff73c, 66, Finished, Available, Finished)
# ✅ Saved markdown to Files/code-conversion-data/solution/code_review_with_details.md

# %%
# code_review_python=o3minicall(code_review_python,"high")
# print(code_review_python.choices[0].message.content)

# %%
# 1️⃣  Call the model
code_review_python=o3minicall(code_review_python,"high")
python_output = code_review_python.choices[0].message.content

# 2️⃣  Destination: remove the "file:" prefix and (optionally) create the folder first
folder_path = "Files/code-conversion-data/solution"   # absolute OneLake path
file_name   = "code_review_just_python_output_with_details.py"
dest_path   = f"{folder_path}/{file_name}"

from notebookutils import mssparkutils   # Fabric import

# Make sure the folder exists (creates it if missing)
mssparkutils.fs.mkdirs(folder_path)

# 3️⃣  Write the markdown file
mssparkutils.fs.put(dest_path, python_output, overwrite=True)
print(f"✅ Saved markdown to {dest_path}")
# Out:
# StatementMeta(, 86022f1e-6446-40c9-84dc-198bd42ff73c, 69, Submitted, Running, Running)
